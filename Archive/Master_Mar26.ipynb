# %% [markdown]
# # Project 2 - Team 4

# %% [markdown]
# ## Objective
#
# Obtain resources from Multiple Listing Service and State of Texas websites to extract, transform, and load csv files to conduct an informative analysis in the future to help our clients to find the perfect house with the perfect school.

# %% [markdown]
# ## Type DataBase
# •	SQL Postgres

# %% [markdown]
# ## HAR Data

# %% [markdown]
# ### Extraction

# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
from secrets import username, password

# %%
# Store csv into df
csv_file= "./Resources/HAR.csv"
raw_har_df= pd.read_csv(csv_file)
raw_har_df
# Out:
#            mls  street_number        street_name unit      city    zip  \
# 0       242718           5407  Chevy Chase Drive  NaN   Houston  77056
# 1       296833           4011  Starbright Street  NaN   Houston  77018
# 2       468622           1030    Creekmont Drive  NaN   Houston  77091
# 3       474952             42   Broad Oaks Drive  NaN   Houston  77056
# 4       531033          12322    Honeywood Trail  NaN   Houston  77077
# ...        ...            ...                ...  ...       ...    ...
# 3236  98662125           9907       Adeline Lane  NaN   Houston  77054
# 3237  98769547           3765    Drummond Street  NaN   Houston  77025
# 3238  98783237           6403          Newcastle  NaN  Bellaire  77401
# 3239  98915588           2414            Freeman  NaN   Houston  77009
# 3240  98990945          13918   Swiss Hill Drive  NaN   Houston  77077
#
#       county                   subdivision      home_type  year_built  ...  \
# 0     Harris               Del Monte Place  Single-Family        1970  ...
# 1     Harris              Oak Forest Manor  Single-Family        2020  ...
# 2     Harris  Shepherd Park Terrace Sec 01  Single-Family        1971  ...
# 3     Harris                    Broad Oaks  Single-Family        1964  ...
# 4     Harris           Ashford Forest Lake  Single-Family        1971  ...
# ...      ...                           ...            ...         ...  ...
# 3236  Harris              Buffalo Speedway  Single-Family        2004  ...
# 3237  Harris          Braes Heights Sec 09  Single-Family        2007  ...
# 3238  Harris            Westmoreland Farms  Single-Family        2003  ...
# 3239  Harris                     Allen A C  Single-Family        1930  ...
# 3240  Harris             Briarhills Sec 01  Single-Family        1977  ...
#
#                     style  list_price  market_area                      area  \
# 0             Traditional      875000           22                  Galleria
# 1             Traditional      378170            9      Oak Forest East Area
# 2             Traditional      355999            9  Shepherd Park Plaza Area
# 3             Traditional     1390000           22           Tanglewood Area
# 4             Traditional      850000           31           Energy Corridor
# ...                   ...         ...          ...                       ...
# 3236          Traditional      309999           18       Medical Center Area
# 3237          Traditional     1399000           17           Braeswood Place
# 3238  Contemporary/Modern     1995000           17             Bellaire Area
# 3239          Traditional      425000            9                 Northside
# 3240          Traditional      305000           31           Energy Corridor
#
#       dom  cdom  list_date  school_district               elementary  \
# 0      85    85      44148      HOUSTON ISD    BRIARGROVE ELEMENTARY
# 1     337   337      43896      HOUSTON ISD    OAK FOREST ELEMENTARY
# 2      50    50      44176      HOUSTON ISD  HIGHLAND HTS ELEMENTARY
# 3     184   184      44049      HOUSTON ISD    BRIARGROVE ELEMENTARY
# 4     105   105      44128      HOUSTON ISD   SHADOWBRIAR ELEMENTARY
# ...   ...   ...        ...              ...                      ...
# 3236    5   593      44228      HOUSTON ISD        SHEARN ELEMENTARY
# 3237   24    24      44209      HOUSTON ISD         TWAIN ELEMENTARY
# 3238   89    89      44053      HOUSTON ISD          HORN ELEMENTARY
# 3239   64   206      44169      HOUSTON ISD      KETELSEN ELEMENTARY
# 3240   99    99      44134      HOUSTON ISD          BUSH ELEMENTARY
#
#                      high_school
# 0             WISDOM HIGH SCHOOL
# 1            WALTRIP HIGH SCHOOL
# 2     WASHINGTON B T HIGH SCHOOL
# 3             WISDOM HIGH SCHOOL
# 4           WESTSIDE HIGH SCHOOL
# ...                          ...
# 3236         MADISON HIGH SCHOOL
# 3237           LAMAR HIGH SCHOOL
# 3238        BELLAIRE HIGH SCHOOL
# 3239       NORTHSIDE HIGH SCHOOL
# 3240        WESTSIDE HIGH SCHOOL
#
# [3241 rows x 29 columns]

# %% [markdown]
# ### Transformation

# %%
# replace elementary with el to match TEA table
raw_har1_df= raw_har_df.replace({"elementary" :"ELEMENTARY"}, "EL", regex = True)
raw_har1_df = raw_har1_df.replace(np.nan, '', regex=True)
raw_har1_df
# Out:
#            mls  street_number        street_name unit      city    zip  \
# 0       242718           5407  Chevy Chase Drive        Houston  77056
# 1       296833           4011  Starbright Street        Houston  77018
# 2       468622           1030    Creekmont Drive        Houston  77091
# 3       474952             42   Broad Oaks Drive        Houston  77056
# 4       531033          12322    Honeywood Trail        Houston  77077
# ...        ...            ...                ...  ...       ...    ...
# 3236  98662125           9907       Adeline Lane        Houston  77054
# 3237  98769547           3765    Drummond Street        Houston  77025
# 3238  98783237           6403          Newcastle       Bellaire  77401
# 3239  98915588           2414            Freeman        Houston  77009
# 3240  98990945          13918   Swiss Hill Drive        Houston  77077
#
#       county                   subdivision      home_type  year_built  ...  \
# 0     Harris               Del Monte Place  Single-Family        1970  ...
# 1     Harris              Oak Forest Manor  Single-Family        2020  ...
# 2     Harris  Shepherd Park Terrace Sec 01  Single-Family        1971  ...
# 3     Harris                    Broad Oaks  Single-Family        1964  ...
# 4     Harris           Ashford Forest Lake  Single-Family        1971  ...
# ...      ...                           ...            ...         ...  ...
# 3236  Harris              Buffalo Speedway  Single-Family        2004  ...
# 3237  Harris          Braes Heights Sec 09  Single-Family        2007  ...
# 3238  Harris            Westmoreland Farms  Single-Family        2003  ...
# 3239  Harris                     Allen A C  Single-Family        1930  ...
# 3240  Harris             Briarhills Sec 01  Single-Family        1977  ...
#
#                     style  list_price  market_area                      area  \
# 0             Traditional      875000           22                  Galleria
# 1             Traditional      378170            9      Oak Forest East Area
# 2             Traditional      355999            9  Shepherd Park Plaza Area
# 3             Traditional     1390000           22           Tanglewood Area
# 4             Traditional      850000           31           Energy Corridor
# ...                   ...         ...          ...                       ...
# 3236          Traditional      309999           18       Medical Center Area
# 3237          Traditional     1399000           17           Braeswood Place
# 3238  Contemporary/Modern     1995000           17             Bellaire Area
# 3239          Traditional      425000            9                 Northside
# 3240          Traditional      305000           31           Energy Corridor
#
#       dom  cdom  list_date  school_district       elementary  \
# 0      85    85      44148      HOUSTON ISD    BRIARGROVE EL
# 1     337   337      43896      HOUSTON ISD    OAK FOREST EL
# 2      50    50      44176      HOUSTON ISD  HIGHLAND HTS EL
# 3     184   184      44049      HOUSTON ISD    BRIARGROVE EL
# 4     105   105      44128      HOUSTON ISD   SHADOWBRIAR EL
# ...   ...   ...        ...              ...              ...
# 3236    5   593      44228      HOUSTON ISD        SHEARN EL
# 3237   24    24      44209      HOUSTON ISD         TWAIN EL
# 3238   89    89      44053      HOUSTON ISD          HORN EL
# 3239   64   206      44169      HOUSTON ISD      KETELSEN EL
# 3240   99    99      44134      HOUSTON ISD          BUSH EL
#
#                      high_school
# 0             WISDOM HIGH SCHOOL
# 1            WALTRIP HIGH SCHOOL
# 2     WASHINGTON B T HIGH SCHOOL
# 3             WISDOM HIGH SCHOOL
# 4           WESTSIDE HIGH SCHOOL
# ...                          ...
# 3236         MADISON HIGH SCHOOL
# 3237           LAMAR HIGH SCHOOL
# 3238        BELLAIRE HIGH SCHOOL
# 3239       NORTHSIDE HIGH SCHOOL
# 3240        WESTSIDE HIGH SCHOOL
#
# [3241 rows x 29 columns]

# %%
# replace high school with h s to match TEA table
customer_data_df = raw_har1_df.replace({"high_school" :"HIGH SCHOOL"}, "H S", regex = True)
customer_data_df.fillna('',inplace=True)
customer_data_df
# Out:
#            mls  street_number        street_name unit      city    zip  \
# 0       242718           5407  Chevy Chase Drive        Houston  77056
# 1       296833           4011  Starbright Street        Houston  77018
# 2       468622           1030    Creekmont Drive        Houston  77091
# 3       474952             42   Broad Oaks Drive        Houston  77056
# 4       531033          12322    Honeywood Trail        Houston  77077
# ...        ...            ...                ...  ...       ...    ...
# 3236  98662125           9907       Adeline Lane        Houston  77054
# 3237  98769547           3765    Drummond Street        Houston  77025
# 3238  98783237           6403          Newcastle       Bellaire  77401
# 3239  98915588           2414            Freeman        Houston  77009
# 3240  98990945          13918   Swiss Hill Drive        Houston  77077
#
#       county                   subdivision      home_type  year_built  ...  \
# 0     Harris               Del Monte Place  Single-Family        1970  ...
# 1     Harris              Oak Forest Manor  Single-Family        2020  ...
# 2     Harris  Shepherd Park Terrace Sec 01  Single-Family        1971  ...
# 3     Harris                    Broad Oaks  Single-Family        1964  ...
# 4     Harris           Ashford Forest Lake  Single-Family        1971  ...
# ...      ...                           ...            ...         ...  ...
# 3236  Harris              Buffalo Speedway  Single-Family        2004  ...
# 3237  Harris          Braes Heights Sec 09  Single-Family        2007  ...
# 3238  Harris            Westmoreland Farms  Single-Family        2003  ...
# 3239  Harris                     Allen A C  Single-Family        1930  ...
# 3240  Harris             Briarhills Sec 01  Single-Family        1977  ...
#
#                     style  list_price  market_area                      area  \
# 0             Traditional      875000           22                  Galleria
# 1             Traditional      378170            9      Oak Forest East Area
# 2             Traditional      355999            9  Shepherd Park Plaza Area
# 3             Traditional     1390000           22           Tanglewood Area
# 4             Traditional      850000           31           Energy Corridor
# ...                   ...         ...          ...                       ...
# 3236          Traditional      309999           18       Medical Center Area
# 3237          Traditional     1399000           17           Braeswood Place
# 3238  Contemporary/Modern     1995000           17             Bellaire Area
# 3239          Traditional      425000            9                 Northside
# 3240          Traditional      305000           31           Energy Corridor
#
#       dom  cdom  list_date  school_district       elementary  \
# 0      85    85      44148      HOUSTON ISD    BRIARGROVE EL
# 1     337   337      43896      HOUSTON ISD    OAK FOREST EL
# 2      50    50      44176      HOUSTON ISD  HIGHLAND HTS EL
# 3     184   184      44049      HOUSTON ISD    BRIARGROVE EL
# 4     105   105      44128      HOUSTON ISD   SHADOWBRIAR EL
# ...   ...   ...        ...              ...              ...
# 3236    5   593      44228      HOUSTON ISD        SHEARN EL
# 3237   24    24      44209      HOUSTON ISD         TWAIN EL
# 3238   89    89      44053      HOUSTON ISD          HORN EL
# 3239   64   206      44169      HOUSTON ISD      KETELSEN EL
# 3240   99    99      44134      HOUSTON ISD          BUSH EL
#
#              high_school
# 0             WISDOM H S
# 1            WALTRIP H S
# 2     WASHINGTON B T H S
# 3             WISDOM H S
# 4           WESTSIDE H S
# ...                  ...
# 3236         MADISON H S
# 3237           LAMAR H S
# 3238        BELLAIRE H S
# 3239       NORTHSIDE H S
# 3240        WESTSIDE H S
#
# [3241 rows x 29 columns]

# %%
# Total info
customer_data_df.shape
# Out:
# (3241, 29)

# %%
# Columns list
customer_data_df.columns
# Out:
# Index(['mls', 'street_number', 'street_name', 'unit', 'city', 'zip', 'county',
#        'subdivision', 'home_type', 'year_built', 'bedrooms', 'full_baths',
#        'half_baths', 'total_baths', 'room_count', 'fireplaces', 'stories',
#        'pool_private', 'garages', 'style', 'list_price', 'market_area', 'area',
#        'dom', 'cdom', 'list_date', 'school_district', 'elementary',
#        'high_school'],
#       dtype='object')

# %%
# Navigate a single column
# customer_data_df['fireplaces']

# %%
# Replace null values with "0"
# customer_data_df['fireplaces']= customer_data_df['fireplaces'].fillna(0)

# %%
# Check replacement
# customer_data_df['fireplaces']

# %%
# Replace null values with "0"
# customer_data_df['garages']= customer_data_df['garages'].fillna(0)

# %%
# Checking unique values
# customer_data_df.nunique()

# %%
# Checking unique values
customer_data_df.nunique().count()
# Out:
# 29

# %%
# isna/isnull
# customer_data_df.isna().sum()

# %%
# Data types
# customer_data_df.dtypes

# %%
# Create new df
HAR_df= customer_data_df
HAR_df
# Out:
#            mls  street_number        street_name unit      city    zip  \
# 0       242718           5407  Chevy Chase Drive        Houston  77056
# 1       296833           4011  Starbright Street        Houston  77018
# 2       468622           1030    Creekmont Drive        Houston  77091
# 3       474952             42   Broad Oaks Drive        Houston  77056
# 4       531033          12322    Honeywood Trail        Houston  77077
# ...        ...            ...                ...  ...       ...    ...
# 3236  98662125           9907       Adeline Lane        Houston  77054
# 3237  98769547           3765    Drummond Street        Houston  77025
# 3238  98783237           6403          Newcastle       Bellaire  77401
# 3239  98915588           2414            Freeman        Houston  77009
# 3240  98990945          13918   Swiss Hill Drive        Houston  77077
#
#       county                   subdivision      home_type  year_built  ...  \
# 0     Harris               Del Monte Place  Single-Family        1970  ...
# 1     Harris              Oak Forest Manor  Single-Family        2020  ...
# 2     Harris  Shepherd Park Terrace Sec 01  Single-Family        1971  ...
# 3     Harris                    Broad Oaks  Single-Family        1964  ...
# 4     Harris           Ashford Forest Lake  Single-Family        1971  ...
# ...      ...                           ...            ...         ...  ...
# 3236  Harris              Buffalo Speedway  Single-Family        2004  ...
# 3237  Harris          Braes Heights Sec 09  Single-Family        2007  ...
# 3238  Harris            Westmoreland Farms  Single-Family        2003  ...
# 3239  Harris                     Allen A C  Single-Family        1930  ...
# 3240  Harris             Briarhills Sec 01  Single-Family        1977  ...
#
#                     style  list_price  market_area                      area  \
# 0             Traditional      875000           22                  Galleria
# 1             Traditional      378170            9      Oak Forest East Area
# 2             Traditional      355999            9  Shepherd Park Plaza Area
# 3             Traditional     1390000           22           Tanglewood Area
# 4             Traditional      850000           31           Energy Corridor
# ...                   ...         ...          ...                       ...
# 3236          Traditional      309999           18       Medical Center Area
# 3237          Traditional     1399000           17           Braeswood Place
# 3238  Contemporary/Modern     1995000           17             Bellaire Area
# 3239          Traditional      425000            9                 Northside
# 3240          Traditional      305000           31           Energy Corridor
#
#       dom  cdom  list_date  school_district       elementary  \
# 0      85    85      44148      HOUSTON ISD    BRIARGROVE EL
# 1     337   337      43896      HOUSTON ISD    OAK FOREST EL
# 2      50    50      44176      HOUSTON ISD  HIGHLAND HTS EL
# 3     184   184      44049      HOUSTON ISD    BRIARGROVE EL
# 4     105   105      44128      HOUSTON ISD   SHADOWBRIAR EL
# ...   ...   ...        ...              ...              ...
# 3236    5   593      44228      HOUSTON ISD        SHEARN EL
# 3237   24    24      44209      HOUSTON ISD         TWAIN EL
# 3238   89    89      44053      HOUSTON ISD          HORN EL
# 3239   64   206      44169      HOUSTON ISD      KETELSEN EL
# 3240   99    99      44134      HOUSTON ISD          BUSH EL
#
#              high_school
# 0             WISDOM H S
# 1            WALTRIP H S
# 2     WASHINGTON B T H S
# 3             WISDOM H S
# 4           WESTSIDE H S
# ...                  ...
# 3236         MADISON H S
# 3237           LAMAR H S
# 3238        BELLAIRE H S
# 3239       NORTHSIDE H S
# 3240        WESTSIDE H S
#
# [3241 rows x 29 columns]

# %%
# Writing to clean csv
# HAR_df.to_csv("./Resources/alt_clean_har.csv", index = False)

# %% [markdown]
# ### Retrieving Latitude and Longitude

# %%
# Creating addresses df
orig_addresses_df = HAR_df[['mls','street_number','street_name','unit','city','zip']]
orig_addresses_df.insert(5,'state','Texas')

orig_addresses_df
# Out:
#            mls  street_number        street_name unit      city  state    zip
# 0       242718           5407  Chevy Chase Drive        Houston  Texas  77056
# 1       296833           4011  Starbright Street        Houston  Texas  77018
# 2       468622           1030    Creekmont Drive        Houston  Texas  77091
# 3       474952             42   Broad Oaks Drive        Houston  Texas  77056
# 4       531033          12322    Honeywood Trail        Houston  Texas  77077
# ...        ...            ...                ...  ...       ...    ...    ...
# 3236  98662125           9907       Adeline Lane        Houston  Texas  77054
# 3237  98769547           3765    Drummond Street        Houston  Texas  77025
# 3238  98783237           6403          Newcastle       Bellaire  Texas  77401
# 3239  98915588           2414            Freeman        Houston  Texas  77009
# 3240  98990945          13918   Swiss Hill Drive        Houston  Texas  77077
#
# [3241 rows x 7 columns]

# %%
orig_addresses_df['full_address'] = orig_addresses_df['street_number'].map(str)+' '+orig_addresses_df['street_name'].map(str)+', '+orig_addresses_df['city'].map(str)+', '+orig_addresses_df['state'].map(str)+', '+orig_addresses_df['zip'].map(str)

orig_addresses_df
# Out:
# <ipython-input-18-9da6da64bf9d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orig_addresses_df['full_address'] = orig_addresses_df['street_number'].map(str)+' '+orig_addresses_df['street_name'].map(str)+', '+orig_addresses_df['city'].map(str)+', '+orig_addresses_df['state'].map(str)+', '+orig_addresses_df['zip'].map(str)
#            mls  street_number        street_name unit      city  state    zip  \
# 0       242718           5407  Chevy Chase Drive        Houston  Texas  77056
# 1       296833           4011  Starbright Street        Houston  Texas  77018
# 2       468622           1030    Creekmont Drive        Houston  Texas  77091
# 3       474952             42   Broad Oaks Drive        Houston  Texas  77056
# 4       531033          12322    Honeywood Trail        Houston  Texas  77077
# ...        ...            ...                ...  ...       ...    ...    ...
# 3236  98662125           9907       Adeline Lane        Houston  Texas  77054
# 3237  98769547           3765    Drummond Street        Houston  Texas  77025
# 3238  98783237           6403          Newcastle       Bellaire  Texas  77401
# 3239  98915588           2414            Freeman        Houston  Texas  77009
# 3240  98990945          13918   Swiss Hill Drive        Houston  Texas  77077
#
#                                        full_address
# 0     5407 Chevy Chase Drive, Houston, Texas, 77056
# 1     4011 Starbright Street, Houston, Texas, 77018
# 2       1030 Creekmont Drive, Houston, Texas, 77091
# 3        42 Broad Oaks Drive, Houston, Texas, 77056
# 4      12322 Honeywood Trail, Houston, Texas, 77077
# ...                                             ...
# 3236       9907 Adeline Lane, Houston, Texas, 77054
# 3237    3765 Drummond Street, Houston, Texas, 77025
# 3238         6403 Newcastle, Bellaire, Texas, 77401
# 3239            2414 Freeman, Houston, Texas, 77009
# 3240  13918 Swiss Hill Drive, Houston, Texas, 77077
#
# [3241 rows x 8 columns]

# %%
addresses_df = orig_addresses_df.drop(['street_number', 'unit','street_name','city','state','zip'], axis =1)
addresses_df
# Out:
#            mls                                   full_address
# 0       242718  5407 Chevy Chase Drive, Houston, Texas, 77056
# 1       296833  4011 Starbright Street, Houston, Texas, 77018
# 2       468622    1030 Creekmont Drive, Houston, Texas, 77091
# 3       474952     42 Broad Oaks Drive, Houston, Texas, 77056
# 4       531033   12322 Honeywood Trail, Houston, Texas, 77077
# ...        ...                                            ...
# 3236  98662125       9907 Adeline Lane, Houston, Texas, 77054
# 3237  98769547    3765 Drummond Street, Houston, Texas, 77025
# 3238  98783237         6403 Newcastle, Bellaire, Texas, 77401
# 3239  98915588            2414 Freeman, Houston, Texas, 77009
# 3240  98990945  13918 Swiss Hill Drive, Houston, Texas, 77077
#
# [3241 rows x 2 columns]

# %%
#******This block of code takes an hour to run due to the time delay required by geopy for free accounts.******  
#****The geocode data has been saved to a .csv that is then read for the remainder of the Jupyter Notebook.****

# Dependencies

#https://geopy.readthedocs.io/en/latest/#specifying-parameters-once
#conda install -c conda-forge geopy

# from geopy.geocoders import Nominatim
# from geopy.extra.rate_limiter import RateLimiter

# loc_address = []
# lat = []
# long = []
# coordinates = []

# geolocator = Nominatim(user_agent="team5")

# geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# for full_address in addresses_df['full_address']:
#     try:
#         inputAddress = full_address
#         location = geolocator.geocode(inputAddress)  #, timeout=15
#         coordinates.append((location.latitude, location.longitude))
#         loc_address.append(inputAddress)
#         lat.append((location.latitude))
#         long.append((location.longitude))
#     except Exception as e:
#         print('Error, skipping address...', e)
 
        
# geocodes_df = pd.DataFrame({'full_address':loc_address,'latitude':lat,'longitude':long,'geocode':coordinates})

# geocodes_df

# %%
# # Merge to reconnect mls

# coord_df=pd.merge(addresses_df,geocodes_df,on = "full_address")

# coord_df.drop_duplicates(subset=['mls'])

# coord_df

# %%
# # Merge to reconnect mls

# final_HAR_df = pd.merge(HAR_df,coord_df,on = "mls")

# final_HAR_df.drop_duplicates(subset=['mls'])

# final_HAR_df.to_csv('./Resources/final_HAR_df.csv')
# final_HAR_df

# %% [markdown]
# ### Convert a pandas dataframe to geojson for web-mapping

# %%
#******This block of code requires the dataframe "final_HAR_df" created in previous section. *****

# %%
# Read csv into df for project purposes
csv_file= "./Resources/final_HAR_df.csv"
final_HAR_df= pd.read_csv(csv_file)
final_HAR_df
# Out:
#       Unnamed: 0       mls  street_number        street_name unit      city  \
# 0              0    242718           5407  Chevy Chase Drive  NaN   Houston
# 1              1    468622           1030    Creekmont Drive  NaN   Houston
# 2              2    531033          12322    Honeywood Trail  NaN   Houston
# 3              3    535780           5708    Dolores  Street    E   Houston
# 4              4    754009           4630             Kermit  NaN   Houston
# ...          ...       ...            ...                ...  ...       ...
# 2793        2793  98652314           6131  Cedar Creek Drive  NaN   Houston
# 2794        2794  98769547           3765    Drummond Street  NaN   Houston
# 2795        2795  98783237           6403          Newcastle  NaN  Bellaire
# 2796        2796  98915588           2414            Freeman  NaN   Houston
# 2797        2797  98990945          13918   Swiss Hill Drive  NaN   Houston
#
#         zip  county                   subdivision      home_type  ...  dom  \
# 0     77056  Harris               Del Monte Place  Single-Family  ...   85
# 1     77091  Harris  Shepherd Park Terrace Sec 01  Single-Family  ...   50
# 2     77077  Harris           Ashford Forest Lake  Single-Family  ...  105
# 3     77057  Harris         Delores Place Estates  Single-Family  ...   32
# 4     77009  Harris                     Sojourner  Single-Family  ...   18
# ...     ...     ...                           ...            ...  ...  ...
# 2793  77057  Harris             Briargrove Sec 08  Single-Family  ...  142
# 2794  77025  Harris          Braes Heights Sec 09  Single-Family  ...   24
# 2795  77401  Harris            Westmoreland Farms  Single-Family  ...   89
# 2796  77009  Harris                     Allen A C  Single-Family  ...   64
# 2797  77077  Harris             Briarhills Sec 01  Single-Family  ...   99
#
#       cdom  list_date  school_district       elementary         high_school  \
# 0       85      44148      HOUSTON ISD    BRIARGROVE EL          WISDOM H S
# 1       50      44176      HOUSTON ISD  HIGHLAND HTS EL  WASHINGTON B T H S
# 2      105      44128      HOUSTON ISD   SHADOWBRIAR EL        WESTSIDE H S
# 3      406      44201      HOUSTON ISD    BRIARGROVE EL          WISDOM H S
# 4       18      44215      HOUSTON ISD      BROWNING EL         HEIGHTS H S
# ...    ...        ...              ...              ...                 ...
# 2793   142      44091      HOUSTON ISD    BRIARGROVE EL          WISDOM H S
# 2794    24      44209      HOUSTON ISD         TWAIN EL           LAMAR H S
# 2795    89      44053      HOUSTON ISD          HORN EL        BELLAIRE H S
# 2796   206      44169      HOUSTON ISD      KETELSEN EL       NORTHSIDE H S
# 2797    99      44134      HOUSTON ISD          BUSH EL        WESTSIDE H S
#
#                                        full_address   latitude  longitude  \
# 0     5407 Chevy Chase Drive, Houston, Texas, 77056  29.745153 -95.469331
# 1       1030 Creekmont Drive, Houston, Texas, 77091  29.842554 -95.422701
# 2      12322 Honeywood Trail, Houston, Texas, 77077  29.758936 -95.599915
# 3       5708 Dolores  Street, Houston, Texas, 77057  29.734376 -95.478795
# 4                4630 Kermit, Houston, Texas, 77009  29.797685 -95.383900
# ...                                             ...        ...        ...
# 2793  6131 Cedar Creek Drive, Houston, Texas, 77057  29.750782 -95.490779
# 2794    3765 Drummond Street, Houston, Texas, 77025  29.695991 -95.436034
# 2795         6403 Newcastle, Bellaire, Texas, 77401  29.705658 -95.451301
# 2796            2414 Freeman, Houston, Texas, 77009  29.782551 -95.363677
# 2797  13918 Swiss Hill Drive, Houston, Texas, 77077  29.766962 -95.632302
#
#                                        geocode
# 0     (29.745153271930764, -95.46933089200235)
# 1     (29.842554067913653, -95.42270099251903)
# 2     (29.758936228182634, -95.59991514697579)
# 3      (29.73437636363636, -95.47879481818181)
# 4     (29.797684538188538, -95.38389982622054)
# ...                                        ...
# 2793  (29.750781773957833, -95.49077900573519)
# 2794  (29.695990884253007, -95.43603430345617)
# 2795                 (29.7056577, -95.4513012)
# 2796   (29.78255085714286, -95.36367742857142)
# 2797  (29.766961636363636, -95.63230218181819)
#
# [2798 rows x 34 columns]

# %%
#Attribution: https://github.com/gboeing/ppd599/blob/3faf7e028d48cb03ddb999c5a910213c5384e7dc/17-Leaflet-Web-Mapping/leaflet-simple-demo/pandas-to-geojson.ipynb

# %%
import pandas as pd, requests, json
import json
from geojson import Feature, FeatureCollection, Point

# %%
# Convert lat-long to floats
final_HAR_df['latitude'] = final_HAR_df['latitude'].astype(float)
final_HAR_df['longitude'] = final_HAR_df['longitude'].astype(float)

# %%
# Kept Columns
useful_cols = ['mls', 'street_number', 'street_name', 'unit', 'city', 'zip','county', 'subdivision', 'home_type', 'year_built', 'bedrooms', 'full_baths', 'half_baths', 'total_baths', 'fireplaces', 'stories','pool_private', 'garages', 'style', 'list_price', 'market_area', 'area', 'dom', 'cdom', 'list_date', 'school_district', 'elementary','high_school','full_address','latitude','longitude']
df_subset = final_HAR_df[useful_cols]

# %%
# Drop any rows that lack lat/long data
df_geo = df_subset.dropna(subset=['latitude', 'longitude'], axis=0, inplace=False)

df_geo = df_geo.applymap(str)

print('We have {} geotagged rows'.format(len(df_geo)))
df_geo.tail()
# Out:
# We have 2798 geotagged rows
#            mls street_number        street_name unit      city    zip  county  \
# 2793  98652314          6131  Cedar Creek Drive  nan   Houston  77057  Harris
# 2794  98769547          3765    Drummond Street  nan   Houston  77025  Harris
# 2795  98783237          6403          Newcastle  nan  Bellaire  77401  Harris
# 2796  98915588          2414            Freeman  nan   Houston  77009  Harris
# 2797  98990945         13918   Swiss Hill Drive  nan   Houston  77077  Harris
#
#                subdivision      home_type year_built  ...             area  \
# 2793     Briargrove Sec 08  Single-Family       2001  ...       Briargrove
# 2794  Braes Heights Sec 09  Single-Family       2007  ...  Braeswood Place
# 2795    Westmoreland Farms  Single-Family       2003  ...    Bellaire Area
# 2796             Allen A C  Single-Family       1930  ...        Northside
# 2797     Briarhills Sec 01  Single-Family       1977  ...  Energy Corridor
#
#       dom cdom list_date school_district     elementary    high_school  \
# 2793  142  142     44091     HOUSTON ISD  BRIARGROVE EL     WISDOM H S
# 2794   24   24     44209     HOUSTON ISD       TWAIN EL      LAMAR H S
# 2795   89   89     44053     HOUSTON ISD        HORN EL   BELLAIRE H S
# 2796   64  206     44169     HOUSTON ISD    KETELSEN EL  NORTHSIDE H S
# 2797   99   99     44134     HOUSTON ISD        BUSH EL   WESTSIDE H S
#
#                                        full_address            latitude  \
# 2793  6131 Cedar Creek Drive, Houston, Texas, 77057  29.750781773957836
# 2794    3765 Drummond Street, Houston, Texas, 77025  29.695990884253007
# 2795         6403 Newcastle, Bellaire, Texas, 77401          29.7056577
# 2796            2414 Freeman, Houston, Texas, 77009   29.78255085714286
# 2797  13918 Swiss Hill Drive, Houston, Texas, 77077   29.76696163636364
#
#                longitude
# 2793   -95.4907790057352
# 2794  -95.43603430345615
# 2795         -95.4513012
# 2796  -95.36367742857142
# 2797   -95.6323021818182
#
# [5 rows x 31 columns]

# %%
def df_to_geojson(df, properties, lat='latitude', lon='longitude'):
    
#     Turn a dataframe containing point data into a geojson formatted python dictionary
    
#     df : the dataframe to convert to geojson
#     properties : a list of columns in the dataframe to turn into geojson feature properties
#     lat : the name of the column in the dataframe that contains latitude data
#     lon : the name of the column in the dataframe that contains longitude data
    
    
    # create a new python dict to contain our geojson data, using geojson format
    geojson = {'type':'FeatureCollection', 'features':[]}

    # loop through each row in the dataframe and convert each row to geojson format
    for _, row in df.iterrows():
        # create a feature template to fill in
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}

        # fill in the coordinates
        feature['geometry']['coordinates'] = [row[lon],row[lat]]

        # for each column, get the value and add it as a new feature property
        for prop in properties:
            feature['properties'][prop] = row[prop]
        
        # add this feature (aka, converted dataframe row) to the list of features inside our dict
        geojson['features'].append(feature)
    
    return geojson

# %%
# Columns for use as Properties
useful_columns = ['mls', 'street_number', 'street_name', 'unit', 'city', 'zip','county', 'subdivision', 'home_type', 'year_built', 'bedrooms', 'full_baths', 'half_baths', 'total_baths', 'fireplaces', 'stories','pool_private', 'garages', 'style', 'list_price', 'market_area', 'area', 'dom', 'cdom', 'list_date', 'school_district', 'elementary','high_school','full_address']

geojson_dict = df_to_geojson(df_geo, properties=useful_columns)
geojson_str = json.dumps(geojson_dict, indent=2)

# %%
# Save the geojson result to a js file suitable for Leaflet
# output_filename = './static/js/dataset.js'
# with open(output_filename, 'w') as output_file:
    
#     output_file.write('var dataset = {};'.format(geojson_str))

# # how many features did we save to the geojson file?
# print('{} geotagged features saved to file'.format(len(geojson_dict['features'])))

# %%
# Save the geojson result to a geojson file
output_filename2 = './static/data/HAR.geojson'
with open(output_filename2, 'w') as output_file2:
    output_file2.write('{}'.format(geojson_str))
    
# how many features did we save to the geojson file?
print('{} geotagged features saved to file'.format(len(geojson_dict['features'])))
# Out:
# 2798 geotagged features saved to file

# %% [markdown]
# ## School Dataframes

# %%
# creating elementary school potion of junction table
raw_mls_el_df = HAR_df[['mls','elementary']]
mls_el_df= raw_mls_el_df.rename(columns= {'elementary': 'school'})
mls_el_df
# Out:
#            mls           school
# 0       242718    BRIARGROVE EL
# 1       296833    OAK FOREST EL
# 2       468622  HIGHLAND HTS EL
# 3       474952    BRIARGROVE EL
# 4       531033   SHADOWBRIAR EL
# ...        ...              ...
# 3236  98662125        SHEARN EL
# 3237  98769547         TWAIN EL
# 3238  98783237          HORN EL
# 3239  98915588      KETELSEN EL
# 3240  98990945          BUSH EL
#
# [3241 rows x 2 columns]

# %%
# creating high school potion of junction table
raw_mls_hs_df = HAR_df[['mls', 'high_school']]
mls_hs_df= raw_mls_hs_df.rename(columns= {'high_school': 'school'})
mls_hs_df
# Out:
#            mls              school
# 0       242718          WISDOM H S
# 1       296833         WALTRIP H S
# 2       468622  WASHINGTON B T H S
# 3       474952          WISDOM H S
# 4       531033        WESTSIDE H S
# ...        ...                 ...
# 3236  98662125         MADISON H S
# 3237  98769547           LAMAR H S
# 3238  98783237        BELLAIRE H S
# 3239  98915588       NORTHSIDE H S
# 3240  98990945        WESTSIDE H S
#
# [3241 rows x 2 columns]

# %%
# concating HAR potion of junction table
frames = [mls_el_df,mls_hs_df]
all_mls_schools_df = pd.concat(frames)
# all_mls_schools_df.to_csv('./Resources/all_mls_schools.csv', index = False)
all_mls_schools_df
# Out:
#            mls           school
# 0       242718    BRIARGROVE EL
# 1       296833    OAK FOREST EL
# 2       468622  HIGHLAND HTS EL
# 3       474952    BRIARGROVE EL
# 4       531033   SHADOWBRIAR EL
# ...        ...              ...
# 3236  98662125      MADISON H S
# 3237  98769547        LAMAR H S
# 3238  98783237     BELLAIRE H S
# 3239  98915588    NORTHSIDE H S
# 3240  98990945     WESTSIDE H S
#
# [6482 rows x 2 columns]

# %% [markdown]
# ## TEA Data

# %% [markdown]
# ### Extraction

# %%
# Store csv into df
csv_file= "./Resources/alt_school_rating_list_tea.csv"
raw_school_rating_df= pd.read_csv(csv_file)
raw_school_rating_df.head()
# Out:
#   Campus\nNumber                         Campus           District  \
# 0      024901001                 FALFURRIAS H S  BROOKS COUNTY ISD
# 1      024901041                 FALFURRIAS J H  BROOKS COUNTY ISD
# 2      024901101                  FALFURRIAS EL  BROOKS COUNTY ISD
# 3      024901103                     LASATER EL  BROOKS COUNTY ISD
# 4      024901105  FALFURRIAS INNOVATION ACADEMY  BROOKS COUNTY ISD
#
#    ESC\nRegion               Region  SBOE\nDistrict  \
# 0          1.0  REGION 01: EDINBURG             3.0
# 1          1.0  REGION 01: EDINBURG             3.0
# 2          1.0  REGION 01: EDINBURG             3.0
# 3          1.0  REGION 01: EDINBURG             3.0
# 4          1.0  REGION 01: EDINBURG             3.0
#
#    # of Consecutive Years Campus is Academically Unacceptable  \
# 0                                                0.0
# 1                                                1.0
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#                       Campus 2020 Rating Campus 2019 Rating  \
# 0  Not Rated: Declared State of Disaster                  B
# 1  Not Rated: Declared State of Disaster                  F
# 2  Not Rated: Declared State of Disaster                  C
# 3  Not Rated: Declared State of Disaster                  C
# 4  Not Rated: Declared State of Disaster                NaN
#
#   Campus 2018 Rating Campus 2017 Rating Campus 2016 Rating  \
# 0       Met Standard       Met Standard       Met Standard
# 1       Met Standard       Met Standard       Met Standard
# 2       Met Standard       Met Standard       Met Standard
# 3       Met Standard       Met Standard       Met Standard
# 4                NaN                NaN                NaN
#
#      Campus 2015 Rating Campus 2014 Rating Campus 2013 Rating  \
# 0          Met Standard       Met Standard       Met Standard
# 1  Improvement Required       Met Standard       Met Standard
# 2          Met Standard       Met Standard       Met Standard
# 3          Met Standard       Met Standard       Met Standard
# 4                   NaN                NaN                NaN
#
#    Campus 2012 Rating         Campus 2011 Rating
# 0                 NaN  Academically Unacceptable
# 1                 NaN  Academically Unacceptable
# 2                 NaN    Academically Acceptable
# 3                 NaN    Academically Acceptable
# 4                 NaN                        NaN

# %% [markdown]
# ### Transformation

# %%
# removing columns not needed
raw_school_rating1_df = raw_school_rating_df.drop(['ESC\nRegion', 'Region', 'SBOE\nDistrict','Campus 2020 Rating',
                                                  'Campus 2018 Rating', 'Campus 2017 Rating','Campus 2016 Rating',
                                                  'Campus 2015 Rating', 'Campus 2014 Rating','Campus 2013 Rating',
                                                  'Campus 2012 Rating','Campus 2011 Rating'], axis =1)
raw_school_rating1_df
# Out:
#                                          Campus\nNumber  \
# 0                                             024901001
# 1                                             024901041
# 2                                             024901101
# 3                                             024901103
# 4                                             024901105
# ...                                                 ...
# 8866                                          232903110
# 8867                   * n/a:  Rating is not available.
# 8868  * 2011 is the last year for the accountability...
# 8869  * No state accountability ratings were assigne...
# 8870  * State accountability ratings were changed to...
#
#                              Campus           District  \
# 0                    FALFURRIAS H S  BROOKS COUNTY ISD
# 1                    FALFURRIAS J H  BROOKS COUNTY ISD
# 2                     FALFURRIAS EL  BROOKS COUNTY ISD
# 3                        LASATER EL  BROOKS COUNTY ISD
# 4     FALFURRIAS INNOVATION ACADEMY  BROOKS COUNTY ISD
# ...                             ...                ...
# 8866                      FLORES EL        UVALDE CISD
# 8867                            NaN                NaN
# 8868                            NaN                NaN
# 8869                            NaN                NaN
# 8870                            NaN                NaN
#
#       # of Consecutive Years Campus is Academically Unacceptable  \
# 0                                                   0.0
# 1                                                   1.0
# 2                                                   0.0
# 3                                                   0.0
# 4                                                   0.0
# ...                                                 ...
# 8866                                                0.0
# 8867                                                NaN
# 8868                                                NaN
# 8869                                                NaN
# 8870                                                NaN
#
#      Campus 2019 Rating
# 0                     B
# 1                     F
# 2                     C
# 3                     C
# 4                   NaN
# ...                 ...
# 8866                  C
# 8867                NaN
# 8868                NaN
# 8869                NaN
# 8870                NaN
#
# [8871 rows x 5 columns]

# %%
# Renaming columns - int is for intermediate (in process) table
int_school_rating_df= raw_school_rating1_df.rename(columns= {'Campus\nNumber': 'campus_number',
                                                            'Campus' : 'school',
                                                            'District' : 'district',
                                                          '# of Consecutive Years Campus is Academically Unacceptable' : 'yrs_unacceptable',
                                                          'Campus 2019 Rating' : 'rating'})
int_school_rating_df
# Out:
#                                           campus_number  \
# 0                                             024901001
# 1                                             024901041
# 2                                             024901101
# 3                                             024901103
# 4                                             024901105
# ...                                                 ...
# 8866                                          232903110
# 8867                   * n/a:  Rating is not available.
# 8868  * 2011 is the last year for the accountability...
# 8869  * No state accountability ratings were assigne...
# 8870  * State accountability ratings were changed to...
#
#                              school           district  yrs_unacceptable  \
# 0                    FALFURRIAS H S  BROOKS COUNTY ISD               0.0
# 1                    FALFURRIAS J H  BROOKS COUNTY ISD               1.0
# 2                     FALFURRIAS EL  BROOKS COUNTY ISD               0.0
# 3                        LASATER EL  BROOKS COUNTY ISD               0.0
# 4     FALFURRIAS INNOVATION ACADEMY  BROOKS COUNTY ISD               0.0
# ...                             ...                ...               ...
# 8866                      FLORES EL        UVALDE CISD               0.0
# 8867                            NaN                NaN               NaN
# 8868                            NaN                NaN               NaN
# 8869                            NaN                NaN               NaN
# 8870                            NaN                NaN               NaN
#
#      rating
# 0         B
# 1         F
# 2         C
# 3         C
# 4       NaN
# ...     ...
# 8866      C
# 8867    NaN
# 8868    NaN
# 8869    NaN
# 8870    NaN
#
# [8871 rows x 5 columns]

# %%
# Adding in new column and associated value
int_school_rating_df['year']= 2019
int_school_rating_df
# Out:
#                                           campus_number  \
# 0                                             024901001
# 1                                             024901041
# 2                                             024901101
# 3                                             024901103
# 4                                             024901105
# ...                                                 ...
# 8866                                          232903110
# 8867                   * n/a:  Rating is not available.
# 8868  * 2011 is the last year for the accountability...
# 8869  * No state accountability ratings were assigne...
# 8870  * State accountability ratings were changed to...
#
#                              school           district  yrs_unacceptable  \
# 0                    FALFURRIAS H S  BROOKS COUNTY ISD               0.0
# 1                    FALFURRIAS J H  BROOKS COUNTY ISD               1.0
# 2                     FALFURRIAS EL  BROOKS COUNTY ISD               0.0
# 3                        LASATER EL  BROOKS COUNTY ISD               0.0
# 4     FALFURRIAS INNOVATION ACADEMY  BROOKS COUNTY ISD               0.0
# ...                             ...                ...               ...
# 8866                      FLORES EL        UVALDE CISD               0.0
# 8867                            NaN                NaN               NaN
# 8868                            NaN                NaN               NaN
# 8869                            NaN                NaN               NaN
# 8870                            NaN                NaN               NaN
#
#      rating  year
# 0         B  2019
# 1         F  2019
# 2         C  2019
# 3         C  2019
# 4       NaN  2019
# ...     ...   ...
# 8866      C  2019
# 8867    NaN  2019
# 8868    NaN  2019
# 8869    NaN  2019
# 8870    NaN  2019
#
# [8871 rows x 6 columns]

# %%
# Dropping rows that contain notes, i.e. start with *
int_school_ratinga_df = int_school_rating_df.drop(int_school_rating_df.loc[int_school_rating_df.campus_number.str.startswith("*")].index)
int_school_ratinga_df
# Out:
#      campus_number                         school           district  \
# 0        024901001                 FALFURRIAS H S  BROOKS COUNTY ISD
# 1        024901041                 FALFURRIAS J H  BROOKS COUNTY ISD
# 2        024901101                  FALFURRIAS EL  BROOKS COUNTY ISD
# 3        024901103                     LASATER EL  BROOKS COUNTY ISD
# 4        024901105  FALFURRIAS INNOVATION ACADEMY  BROOKS COUNTY ISD
# ...            ...                            ...                ...
# 8862     232903102                      DALTON EL        UVALDE CISD
# 8863     232903103                        ROBB EL        UVALDE CISD
# 8864     232903104                      ANTHON EL        UVALDE CISD
# 8865     232903108              BATESVILLE SCHOOL        UVALDE CISD
# 8866     232903110                      FLORES EL        UVALDE CISD
#
#       yrs_unacceptable rating  year
# 0                  0.0      B  2019
# 1                  1.0      F  2019
# 2                  0.0      C  2019
# 3                  0.0      C  2019
# 4                  0.0    NaN  2019
# ...                ...    ...   ...
# 8862               0.0      C  2019
# 8863               2.0      F  2019
# 8864               0.0      C  2019
# 8865               1.0      F  2019
# 8866               0.0      C  2019
#
# [8867 rows x 6 columns]

# %%
# Dropping rows that contain middle school to match HAR data
int_school_rating1_df = int_school_ratinga_df.drop(int_school_ratinga_df.loc[int_school_ratinga_df.school.str.contains("MIDDLE")].index)
int_school_rating1_df
# Out:
#      campus_number                         school           district  \
# 0        024901001                 FALFURRIAS H S  BROOKS COUNTY ISD
# 1        024901041                 FALFURRIAS J H  BROOKS COUNTY ISD
# 2        024901101                  FALFURRIAS EL  BROOKS COUNTY ISD
# 3        024901103                     LASATER EL  BROOKS COUNTY ISD
# 4        024901105  FALFURRIAS INNOVATION ACADEMY  BROOKS COUNTY ISD
# ...            ...                            ...                ...
# 8862     232903102                      DALTON EL        UVALDE CISD
# 8863     232903103                        ROBB EL        UVALDE CISD
# 8864     232903104                      ANTHON EL        UVALDE CISD
# 8865     232903108              BATESVILLE SCHOOL        UVALDE CISD
# 8866     232903110                      FLORES EL        UVALDE CISD
#
#       yrs_unacceptable rating  year
# 0                  0.0      B  2019
# 1                  1.0      F  2019
# 2                  0.0      C  2019
# 3                  0.0      C  2019
# 4                  0.0    NaN  2019
# ...                ...    ...   ...
# 8862               0.0      C  2019
# 8863               2.0      F  2019
# 8864               0.0      C  2019
# 8865               1.0      F  2019
# 8866               0.0      C  2019
#
# [7796 rows x 6 columns]

# %%
# checking for NANs
int_school_rating1_df.isna().sum()
# Out:
# campus_number         0
# school                0
# district              0
# yrs_unacceptable      0
# rating              187
# year                  0
# dtype: int64

# %%
# filling NaNs
int_school_rating1_df = int_school_rating1_df.fillna("Not Rated")

# %%
# checking for NANs
int_school_rating1_df.isna().sum()
# Out:
# campus_number       0
# school              0
# district            0
# yrs_unacceptable    0
# rating              0
# year                0
# dtype: int64

# %%
# looking for unique items in column
int_school_rating1_df.rating.unique()
# Out:
# array(['B', 'F', 'C', 'Not Rated', 'A', 'D',
#        'Not Rated: Minimum Size rules', 'Not rated: Data Integrity Issue'],
#       dtype=object)

# %%
# replacing to get like wording 
int_school_rating2_df = int_school_rating1_df.replace({"rating" :"Not Rated: Minimum Size rules"},"Not Rated", regex = True)
int_school_rating3_df = int_school_rating2_df.replace({"rating" :"Not rated: Data Integrity Issue"},"Not Rated", regex = True)
int_school_rating3_df.head()
# Out:
#   campus_number                         school           district  \
# 0     024901001                 FALFURRIAS H S  BROOKS COUNTY ISD
# 1     024901041                 FALFURRIAS J H  BROOKS COUNTY ISD
# 2     024901101                  FALFURRIAS EL  BROOKS COUNTY ISD
# 3     024901103                     LASATER EL  BROOKS COUNTY ISD
# 4     024901105  FALFURRIAS INNOVATION ACADEMY  BROOKS COUNTY ISD
#
#    yrs_unacceptable     rating  year
# 0               0.0          B  2019
# 1               1.0          F  2019
# 2               0.0          C  2019
# 3               0.0          C  2019
# 4               0.0  Not Rated  2019

# %%
# verifying like wording
int_school_rating3_df.rating.unique()
# Out:
# array(['B', 'F', 'C', 'Not Rated', 'A', 'D'], dtype=object)

# %%
# building dataframe for customer target area
int_school_rating4_df = int_school_rating3_df.loc[(int_school_rating_df['district'] == "HOUSTON ISD")|
                                               (int_school_rating_df['district'] == "KATY ISD") |
                                               (int_school_rating_df['district'] == "SHELDON ISD") |
                                               (int_school_rating_df['district'] == "SPRING BRANCH ISD") |
                                               (int_school_rating_df['district'] == "GALENA PARK ISD") |
                                               (int_school_rating_df['district'] == "CYPRESS-FAIRBANKS ISD") 
                                               ]
int_school_rating4_df
# Out:
#      campus_number                  school               district  \
# 1318     101907002             CY-FAIR H S  CYPRESS-FAIRBANKS ISD
# 1319     101907003      JERSEY VILLAGE H S  CYPRESS-FAIRBANKS ISD
# 1320     101907004       CYPRESS CREEK H S  CYPRESS-FAIRBANKS ISD
# 1321     101907005       LANGHAM CREEK H S  CYPRESS-FAIRBANKS ISD
# 1322     101907007       CYPRESS FALLS H S  CYPRESS-FAIRBANKS ISD
# ...            ...                     ...                    ...
# 2389     101920128  THE WILDCAT WAY SCHOOL      SPRING BRANCH ISD
# 2390     101920129   THE PANDA PATH SCHOOL      SPRING BRANCH ISD
# 2391     101920130    THE LION LANE SCHOOL      SPRING BRANCH ISD
# 2392     101920131    THE BEAR BLVD SCHOOL      SPRING BRANCH ISD
# 2393     101920132  THE TIGER TRAIL SCHOOL      SPRING BRANCH ISD
#
#       yrs_unacceptable rating  year
# 1318               0.0      A  2019
# 1319               0.0      B  2019
# 1320               0.0      B  2019
# 1321               0.0      A  2019
# 1322               0.0      B  2019
# ...                ...    ...   ...
# 2389               0.0      A  2019
# 2390               0.0      B  2019
# 2391               0.0      B  2019
# 2392               0.0      A  2019
# 2393               0.0      C  2019
#
# [454 rows x 6 columns]

# %%
# adding high schools that are on edge of target area (outside of ISD) but still gets kids because of zoning
new_df = int_school_rating3_df.loc[(int_school_rating3_df['campus_number'] =='101911002')]
new1_df = int_school_rating3_df.loc[(int_school_rating3_df['campus_number'] =='101902003')]
new2_df = int_school_rating3_df.loc[(int_school_rating3_df['campus_number'] =='101919001')]

# %%
# adding schools to df
int_school_rating5_df = int_school_rating4_df.append(new_df, ignore_index=True)
int_school_rating6_df = int_school_rating5_df.append(new1_df, ignore_index=True)
int_school_rating7_df = int_school_rating6_df.append(new2_df, ignore_index=True)
int_school_rating7_df
# Out:
#     campus_number                  school               district  \
# 0       101907002             CY-FAIR H S  CYPRESS-FAIRBANKS ISD
# 1       101907003      JERSEY VILLAGE H S  CYPRESS-FAIRBANKS ISD
# 2       101907004       CYPRESS CREEK H S  CYPRESS-FAIRBANKS ISD
# 3       101907005       LANGHAM CREEK H S  CYPRESS-FAIRBANKS ISD
# 4       101907007       CYPRESS FALLS H S  CYPRESS-FAIRBANKS ISD
# ..            ...                     ...                    ...
# 452     101920131    THE BEAR BLVD SCHOOL      SPRING BRANCH ISD
# 453     101920132  THE TIGER TRAIL SCHOOL      SPRING BRANCH ISD
# 454     101911002                 LEE H S       GOOSE CREEK CISD
# 455     101902003           MACARTHUR H S             ALDINE ISD
# 456     101919001              SPRING H S             SPRING ISD
#
#      yrs_unacceptable rating  year
# 0                 0.0      A  2019
# 1                 0.0      B  2019
# 2                 0.0      B  2019
# 3                 0.0      A  2019
# 4                 0.0      B  2019
# ..                ...    ...   ...
# 452               0.0      A  2019
# 453               0.0      C  2019
# 454               0.0      B  2019
# 455               0.0      C  2019
# 456               0.0      C  2019
#
# [457 rows x 6 columns]

# %%
# removing elementary school that is not in the target area ISD - it was causing conflict with primary key
int_school_rating8_df = int_school_rating7_df[int_school_rating7_df.campus_number != '101907152']
int_school_rating8_df
# Out:
#     campus_number                  school               district  \
# 0       101907002             CY-FAIR H S  CYPRESS-FAIRBANKS ISD
# 1       101907003      JERSEY VILLAGE H S  CYPRESS-FAIRBANKS ISD
# 2       101907004       CYPRESS CREEK H S  CYPRESS-FAIRBANKS ISD
# 3       101907005       LANGHAM CREEK H S  CYPRESS-FAIRBANKS ISD
# 4       101907007       CYPRESS FALLS H S  CYPRESS-FAIRBANKS ISD
# ..            ...                     ...                    ...
# 452     101920131    THE BEAR BLVD SCHOOL      SPRING BRANCH ISD
# 453     101920132  THE TIGER TRAIL SCHOOL      SPRING BRANCH ISD
# 454     101911002                 LEE H S       GOOSE CREEK CISD
# 455     101902003           MACARTHUR H S             ALDINE ISD
# 456     101919001              SPRING H S             SPRING ISD
#
#      yrs_unacceptable rating  year
# 0                 0.0      A  2019
# 1                 0.0      B  2019
# 2                 0.0      B  2019
# 3                 0.0      A  2019
# 4                 0.0      B  2019
# ..                ...    ...   ...
# 452               0.0      A  2019
# 453               0.0      C  2019
# 454               0.0      B  2019
# 455               0.0      C  2019
# 456               0.0      C  2019
#
# [456 rows x 6 columns]

# %%
# Creating duplicate df to prevent corruption of original df
school_rating_df= int_school_rating8_df
school_rating_df
# Out:
#     campus_number                  school               district  \
# 0       101907002             CY-FAIR H S  CYPRESS-FAIRBANKS ISD
# 1       101907003      JERSEY VILLAGE H S  CYPRESS-FAIRBANKS ISD
# 2       101907004       CYPRESS CREEK H S  CYPRESS-FAIRBANKS ISD
# 3       101907005       LANGHAM CREEK H S  CYPRESS-FAIRBANKS ISD
# 4       101907007       CYPRESS FALLS H S  CYPRESS-FAIRBANKS ISD
# ..            ...                     ...                    ...
# 452     101920131    THE BEAR BLVD SCHOOL      SPRING BRANCH ISD
# 453     101920132  THE TIGER TRAIL SCHOOL      SPRING BRANCH ISD
# 454     101911002                 LEE H S       GOOSE CREEK CISD
# 455     101902003           MACARTHUR H S             ALDINE ISD
# 456     101919001              SPRING H S             SPRING ISD
#
#      yrs_unacceptable rating  year
# 0                 0.0      A  2019
# 1                 0.0      B  2019
# 2                 0.0      B  2019
# 3                 0.0      A  2019
# 4                 0.0      B  2019
# ..                ...    ...   ...
# 452               0.0      A  2019
# 453               0.0      C  2019
# 454               0.0      B  2019
# 455               0.0      C  2019
# 456               0.0      C  2019
#
# [456 rows x 6 columns]

# %%
# Writing to clean csv
# school_rating_df.to_csv('./Resources/alt_clean_ratings.csv', index = False)

# %%
raw_cnum_school_df = school_rating_df[['campus_number','school']]
# raw_cnum_school_df .to_csv("./Resources/raw_cnum_school.csv", index = False)
raw_cnum_school_df
# Out:
#     campus_number                  school
# 0       101907002             CY-FAIR H S
# 1       101907003      JERSEY VILLAGE H S
# 2       101907004       CYPRESS CREEK H S
# 3       101907005       LANGHAM CREEK H S
# 4       101907007       CYPRESS FALLS H S
# ..            ...                     ...
# 452     101920131    THE BEAR BLVD SCHOOL
# 453     101920132  THE TIGER TRAIL SCHOOL
# 454     101911002                 LEE H S
# 455     101902003           MACARTHUR H S
# 456     101919001              SPRING H S
#
# [456 rows x 2 columns]

# %%
raw_junction = pd.merge_ordered(all_mls_schools_df, raw_cnum_school_df, fill_method='ffill', left_by='school')
# raw_junction.to_csv("./Resources/raw_junction.csv", index = False)
raw_junction
# Out:
#            mls                   school campus_number
# 0       242718            BRIARGROVE EL     101912116
# 1       474952            BRIARGROVE EL     101912116
# 2       535780            BRIARGROVE EL     101912116
# 3      3483628            BRIARGROVE EL     101912116
# 4      3724611            BRIARGROVE EL     101912116
# ...        ...                      ...           ...
# 6477  68258530               SPRING H S     101919001
# 6478  67260428                  LEE H S     101911002
# 6479  76980935                  LEE H S     101911002
# 6480  71235874          GALENA PARK H S     101910002
# 6481  71507597  NORTH SHORE SENIOR HIGH     101910003
#
# [6482 rows x 3 columns]

# %%
# triple mls check - if dup school names in target area - will cause 3 mls nubers to show
trip_school_rating = raw_junction.pivot_table(index= ['mls'], aggfunc= 'size')
trip_school_rating.sort_values(ascending=False)
# Out:
# mls
# 242718      2
# 66596195    2
# 66232995    2
# 66254848    2
# 66270166    2
#            ..
# 34799457    2
# 34817296    2
# 34830405    2
# 34835352    2
# 98990945    2
# Length: 3241, dtype: int64

# %%
sorted_raw_junction = raw_junction.sort_values(by=['mls'])
sorted_raw_junction
# Out:
#            mls              school campus_number
# 0       242718       BRIARGROVE EL     101912116
# 3241    242718          WISDOM H S     101912009
# 3479    296833         WALTRIP H S     101912015
# 188     296833       OAK FOREST EL     101912211
# 3810    468622  WASHINGTON B T H S     101912016
# ...        ...                 ...           ...
# 2153  98783237             HORN EL     101912178
# 6012  98915588       NORTHSIDE H S     101912003
# 1366  98915588         KETELSEN EL     101912389
# 2419  98990945             BUSH EL     101912275
# 4131  98990945        WESTSIDE H S     101912036
#
# [6482 rows x 3 columns]

# %%
raw_har2_df = sorted_raw_junction.drop(['school'], axis =1)
raw_har2_df
# Out:
#            mls campus_number
# 0       242718     101912116
# 3241    242718     101912009
# 3479    296833     101912015
# 188     296833     101912211
# 3810    468622     101912016
# ...        ...           ...
# 2153  98783237     101912178
# 6012  98915588     101912003
# 1366  98915588     101912389
# 2419  98990945     101912275
# 4131  98990945     101912036
#
# [6482 rows x 2 columns]

# %%
# # Writing to clean csv
raw_har2_df.to_csv("./Resources/raw_har2.csv", index = False)

# %% [markdown]
# ## Junction Table

# %%
# Store csv into df
csv_file= "./Resources/raw_HAR2.csv"
junction_df= pd.read_csv(csv_file)
junction_df
# Out:
#            mls  campus_number
# 0       242718      101912116
# 1       242718      101912009
# 2       296833      101912015
# 3       296833      101912211
# 4       468622      101912016
# ...        ...            ...
# 6477  98783237      101912178
# 6478  98915588      101912003
# 6479  98915588      101912389
# 6480  98990945      101912275
# 6481  98990945      101912036
#
# [6482 rows x 2 columns]

# %% [markdown]
# # Load to SQL

# %%
# Connect to local database
rds_connection_string = f"{username}:{password}@localhost:5432/etl_team5"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Use pandas to load transformed df into table school_rating_df
school_rating_df.to_sql(name='school_rating', con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     508         # inherits the docstring from interfaces.Dialect.connect
# --> 509         return self.dbapi.connect(*cargs, **cparams)
#     510
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-63-cb1d18a7599b> in <module>
#       1 # Use pandas to load transformed df into table school_rating_df
# ----> 2 school_rating_df.to_sql(name='school_rating', con=engine, if_exists='replace', index=False)
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2774         from pandas.io import sql
#    2775
# -> 2776         sql.to_sql(
#    2777             self,
#    2778             name,
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     588         )
#     589
# --> 590     pandas_sql.to_sql(
#     591         frame,
#     592         name,
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1390             dtype=dtype,
#    1391         )
# -> 1392         table.create()
#    1393
#    1394         from sqlalchemy import exc
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\pandas\io\sql.py in create(self)
#     720
#     721     def create(self):
# --> 722         if self.exists():
#     723             if self.if_exists == "fail":
#     724                 raise ValueError(f"Table '{self.name}' already exists.")
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\pandas\io\sql.py in exists(self)
#     707
#     708     def exists(self):
# --> 709         return self.pd_sql.has_table(self.name, self.schema)
#     710
#     711     def sql_schema(self):
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1427
#    1428     def has_table(self, name, schema=None):
# -> 1429         return self.connectable.run_callable(
#    1430             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1431         )
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2209
#    2210         """
# -> 2211         with self._contextual_connect() as conn:
#    2212             return conn.run_callable(callable_, *args, **kwargs)
#    2213
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2300         return self._connection_cls(
#    2301             self,
# -> 2302             self._wrap_pool_connect(self.pool.connect, None),
#    2303             close_with_result=close_with_result,
#    2304             **kwargs
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
# -> 2339                 Connection._handle_dbapi_exception_noconnection(
#    2340                     e, dialect, self
#    2341                 )
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1581             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1582         elif should_wrap:
# -> 1583             util.raise_(
#    1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     507     def connect(self, *cargs, **cparams):
#     508         # inherits the docstring from interfaces.Dialect.connect
# --> 509         return self.dbapi.connect(*cargs, **cparams)
#     510
#     511     def create_connect_args(self, url):
#
# ~\anaconda3\envs\SQLearn\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# Use pandas to load transformed df into table mls
HAR_df.to_sql(name='mls', con=engine, if_exists='replace', index=False)

# %%
# Use pandas to load transformed df into table junction_table
junction_df.to_sql(name='junction_table', con=engine, if_exists='replace', index=False)

# %% [markdown]
# ## SQL Query of tables

# %%
# Confirm data has been added by querying the school_rating table
pd.read_sql_query('select * from school_rating', con=engine).head()

# %%
# Confirm data has been added by querying the mls table
pd.read_sql_query('select * from mls', con=engine).head()

# %%
# Confirm data has been added by querying the junction_table table
pd.read_sql_query('select * from junction_table', con=engine).head()

# %%
# Check for tables
engine.table_names()
