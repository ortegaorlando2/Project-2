# %% [markdown]
# # Project 2 - Team 5

# %% [markdown]
# ## Objective
#
# Obtain resources from Multiple Listing Service and State of Texas websites to extract, transform, and load csv files to conduct an informative analysis in the future to help our clients to find the perfect house with the perfect school.

# %% [markdown]
# ## Type DataBase
# •	SQL Postgres

# %% [markdown]
# ## HAR Data

# %% [markdown]
# ### Extraction

# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
from secrets import username, password

# %%
# Store csv into df
csv_file= "../Resources/small_alt_HAR.csv"  #Change to smaller file for latlong coding
raw_har_df= pd.read_csv(csv_file)
raw_har_df
# Out:
#          mls  street_number       street_name  unit     city    zip  county  \
# 0   90227486           2403     Austin Street   NaN  Houston  77004  Harris
# 1   76269817           3123     Austin Street   NaN  Houston  77004  Harris
# 2   44013547           3108   Crawford Street   NaN  Houston  77004  Harris
# 3   78420188           3110   Crawford Street   NaN  Houston  77004  Harris
# 4   32279965           1804     Dennis Street   NaN  Houston  77004  Harris
# 5   12892280           1411      Elgin Street   NaN  Houston  77004  Harris
# 6   47688089           1527    FRANCIS Street   NaN  Houston  77004  Harris
# 7   14702643           1611     Holman Street   NaN  Houston  77004  Harris
# 8   23353569           1713     Holman Street   NaN  Houston  77004  Harris
# 9   95756492           1315   Isabella Street   NaN  Houston  77004  Harris
# 10  52061919           1319   Isabella Street   NaN  Houston  77004  Harris
# 11  13938486           3203  La Branch Street   NaN  Houston  77004  Harris
# 12  77592370           1503     Stuart Street   NaN  Houston  77004  Harris
# 13  87702589           1505     Stuart Street   NaN  Houston  77004  Harris
# 14   8797838            504      Anita Street   NaN  Houston  77006  Harris
# 15  43111391            227   Avondale Street   NaN  Houston  77006  Harris
# 16  59046521            302     Dennis Street   NaN  Houston  77006  Harris
# 17  29513112            124       Drew Street   NaN  Houston  77006  Harris
# 18  82691736           1004  Cleveland Street   NaN  Houston  77019  Harris
# 19  13863906           1106      Oneil Street   NaN  Houston  77019  Harris
# 20  71466098           1112      Robin Street   NaN  Houston  77019  Harris
# 21  95801397           1504   Saulnier Street   NaN  Houston  77019  Harris
# 22  49786342           1506   Saulnier Street   NaN  Houston  77019  Harris
# 23  89590051           1508   Saulnier Street   NaN  Houston  77019  Harris
# 24  49821838           1610     Victor Street   NaN  Houston  77019  Harris
# 25  67264587           1314         Hadley St   NaN  Houston  77002  Harris
# 26  21315276           1316         Hadley St   NaN  Houston  77002  Harris
# 27  11725906           3405     Audubon Place   NaN  Houston  77006  Harris
# 28  56775365              4  Courtlandt Place   NaN  Houston  77006  Harris
#
#                      subdivision      home_type  year_built  ...  \
# 0                 Austin Skyline  Single-Family        2015  ...
# 1      Montione Vls/Elgin Pt Rep  Single-Family        2014  ...
# 2                        Midtown  Single-Family           0  ...
# 3                        Midtown  Single-Family           0  ...
# 4            Weekley at Chenvert  Single-Family        2014  ...
# 5      Montione Vls/Elgin Pt Rep  Single-Family        2014  ...
# 6                FRANCIS STATION  Single-Family        2000  ...
# 7               Holman Outlot 38  Single-Family        2013  ...
# 8                        Midtown  Single-Family        2019  ...
# 9               Midtown Elevated  Single-Family        2019  ...
# 10              Midtown Elevated  Single-Family        2019  ...
# 11  Colina Homes/Labranch Street  Single-Family        2017  ...
# 12                Stuart Terrace  Single-Family        2021  ...
# 13                Stuart Terrace  Single-Family        2021  ...
# 14                   Fairgrounds  Single-Family        1999  ...
# 15                      Montrose  Single-Family        2014  ...
# 16                   Fairgrounds  Single-Family        2005  ...
# 17                  Drew Gardens  Single-Family        2006  ...
# 18               Skyline/Midtown  Single-Family        2015  ...
# 19                      Runnells  Single-Family        1900  ...
# 20                 Enclave/Robin  Single-Family        2015  ...
# 21         Allen Pines Lofts Sub  Single-Family        2020  ...
# 22         Allen Pines Lofts Sub  Single-Family        2020  ...
# 23         Allen Pines Lofts Sub  Single-Family        2020  ...
# 24                Baker W R Ssbb  Single-Family        2020  ...
# 25           Austin Hadley Place  Single-Family        2007  ...
# 26           Austin Hadley Place  Single-Family        2007  ...
# 27                      Montrose  Single-Family        1920  ...
# 28              COURTLANDT PLACE  Single-Family        1910  ...
#
#                                style  list_price  market_area  \
# 0                Contemporary/Modern      445000           16
# 1                      Mediterranean      489000           16
# 2                Contemporary/Modern      429000           16
# 3                Contemporary/Modern      439000           16
# 4   Contemporary/Modern, Traditional      404000           16
# 5                        Traditional      429000           16
# 6                        Traditional      320000           16
# 7         Mediterranean, Traditional     1075000           16
# 8                Contemporary/Modern      609900           16
# 9                        Traditional      629900           16
# 10                       Traditional      534800           16
# 11               Contemporary/Modern      539000           16
# 12               Contemporary/Modern      996075           16
# 13               Contemporary/Modern      936925           16
# 14               Contemporary/Modern      485000           16
# 15                       Traditional      520000           16
# 16                       Traditional     1120000           16
# 17               Contemporary/Modern      496500           16
# 18               Contemporary/Modern      500000           16
# 19                       Traditional      995000           16
# 20                     Mediterranean      475000           16
# 21               Contemporary/Modern      525000           16
# 22               Contemporary/Modern      525000           16
# 23               Contemporary/Modern      525000           16
# 24               Contemporary/Modern      699900           16
# 25                       Traditional      450000           16
# 26               Contemporary/Modern      499000           16
# 27                       Traditional      585000           16
# 28          Other Style, Traditional     3250000           16
#
#                  area  dom  cdom   list_date  school_district  \
# 0   Midtown - Houston  150   150    9/9/2020      HOUSTON ISD
# 1   Midtown - Houston   30    30    1/7/2021      HOUSTON ISD
# 2   Midtown - Houston  135   135   9/24/2020      HOUSTON ISD
# 3   Midtown - Houston  135   135   9/24/2020      HOUSTON ISD
# 4   Midtown - Houston   36    36    1/1/2021      HOUSTON ISD
# 5   Midtown - Houston    5    45    2/1/2021      HOUSTON ISD
# 6   Midtown - Houston   20    20  11/16/2020      HOUSTON ISD
# 7   Midtown - Houston   59   423   12/9/2020      HOUSTON ISD
# 8   Midtown - Houston   66   485   12/2/2020      HOUSTON ISD
# 9   Midtown - Houston   12   962   1/25/2021      HOUSTON ISD
# 10  Midtown - Houston   12   962   1/25/2021      HOUSTON ISD
# 11  Midtown - Houston   95    95   11/3/2020      HOUSTON ISD
# 12  Midtown - Houston   80    80  11/18/2020      HOUSTON ISD
# 13  Midtown - Houston   80    80  11/18/2020      HOUSTON ISD
# 14  Midtown - Houston   75    75  11/23/2020      HOUSTON ISD
# 15  Midtown - Houston  125   125   10/4/2020      HOUSTON ISD
# 16  Midtown - Houston   75   161  11/23/2020      HOUSTON ISD
# 17  Midtown - Houston  236   236   6/15/2020      HOUSTON ISD
# 18  Midtown - Houston   32   155    1/5/2021      HOUSTON ISD
# 19  Midtown - Houston  216   216    7/5/2020      HOUSTON ISD
# 20  Midtown - Houston   21    21   1/16/2021      HOUSTON ISD
# 21  Midtown - Houston   97   314   11/1/2020      HOUSTON ISD
# 22  Midtown - Houston  109   109  10/20/2020      HOUSTON ISD
# 23  Midtown - Houston  109   109  10/20/2020      HOUSTON ISD
# 24  Midtown - Houston   47    47   11/6/2020      HOUSTON ISD
# 25  Midtown - Houston   64    64   12/4/2020      HOUSTON ISD
# 26  Midtown - Houston   17   109   1/20/2021      HOUSTON ISD
# 27           Montrose   25    25   1/12/2021      HOUSTON ISD
# 28           Montrose   80   242  11/18/2020      HOUSTON ISD
#
#                            elementary          high_school
# 0              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 1              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 2              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 3              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 4              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 5              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 6              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 7              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 8              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 9              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 10             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 11             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 12             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 13             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 14             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 15  WHARTON K-8 DUAL LANGUAGE ACADEMY    LAMAR HIGH SCHOOL
# 16             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 17             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 18             GREGORY-LINCOLN ED CTR  HEIGHTS HIGH SCHOOL
# 19             GREGORY-LINCOLN ED CTR  HEIGHTS HIGH SCHOOL
# 20             GREGORY-LINCOLN ED CTR  HEIGHTS HIGH SCHOOL
# 21             GREGORY-LINCOLN ED CTR  HEIGHTS HIGH SCHOOL
# 22             GREGORY-LINCOLN ED CTR  HEIGHTS HIGH SCHOOL
# 23             GREGORY-LINCOLN ED CTR  HEIGHTS HIGH SCHOOL
# 24             GREGORY-LINCOLN ED CTR  HEIGHTS HIGH SCHOOL
# 25             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 26             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 27               MACGREGOR ELEMENTARY    LAMAR HIGH SCHOOL
# 28               MACGREGOR ELEMENTARY    LAMAR HIGH SCHOOL
#
# [29 rows x 29 columns]

# %% [markdown]
# ### Transformation

# %%
# replace elementary with el to match TEA table
raw_har1_df= raw_har_df.replace({"elementary" :"ELEMENTARY"}, "EL", regex = True)
raw_har1_df
# Out:
#          mls  street_number       street_name  unit     city    zip  county  \
# 0   90227486           2403     Austin Street   NaN  Houston  77004  Harris
# 1   76269817           3123     Austin Street   NaN  Houston  77004  Harris
# 2   44013547           3108   Crawford Street   NaN  Houston  77004  Harris
# 3   78420188           3110   Crawford Street   NaN  Houston  77004  Harris
# 4   32279965           1804     Dennis Street   NaN  Houston  77004  Harris
# 5   12892280           1411      Elgin Street   NaN  Houston  77004  Harris
# 6   47688089           1527    FRANCIS Street   NaN  Houston  77004  Harris
# 7   14702643           1611     Holman Street   NaN  Houston  77004  Harris
# 8   23353569           1713     Holman Street   NaN  Houston  77004  Harris
# 9   95756492           1315   Isabella Street   NaN  Houston  77004  Harris
# 10  52061919           1319   Isabella Street   NaN  Houston  77004  Harris
# 11  13938486           3203  La Branch Street   NaN  Houston  77004  Harris
# 12  77592370           1503     Stuart Street   NaN  Houston  77004  Harris
# 13  87702589           1505     Stuart Street   NaN  Houston  77004  Harris
# 14   8797838            504      Anita Street   NaN  Houston  77006  Harris
# 15  43111391            227   Avondale Street   NaN  Houston  77006  Harris
# 16  59046521            302     Dennis Street   NaN  Houston  77006  Harris
# 17  29513112            124       Drew Street   NaN  Houston  77006  Harris
# 18  82691736           1004  Cleveland Street   NaN  Houston  77019  Harris
# 19  13863906           1106      Oneil Street   NaN  Houston  77019  Harris
# 20  71466098           1112      Robin Street   NaN  Houston  77019  Harris
# 21  95801397           1504   Saulnier Street   NaN  Houston  77019  Harris
# 22  49786342           1506   Saulnier Street   NaN  Houston  77019  Harris
# 23  89590051           1508   Saulnier Street   NaN  Houston  77019  Harris
# 24  49821838           1610     Victor Street   NaN  Houston  77019  Harris
# 25  67264587           1314         Hadley St   NaN  Houston  77002  Harris
# 26  21315276           1316         Hadley St   NaN  Houston  77002  Harris
# 27  11725906           3405     Audubon Place   NaN  Houston  77006  Harris
# 28  56775365              4  Courtlandt Place   NaN  Houston  77006  Harris
#
#                      subdivision      home_type  year_built  ...  \
# 0                 Austin Skyline  Single-Family        2015  ...
# 1      Montione Vls/Elgin Pt Rep  Single-Family        2014  ...
# 2                        Midtown  Single-Family           0  ...
# 3                        Midtown  Single-Family           0  ...
# 4            Weekley at Chenvert  Single-Family        2014  ...
# 5      Montione Vls/Elgin Pt Rep  Single-Family        2014  ...
# 6                FRANCIS STATION  Single-Family        2000  ...
# 7               Holman Outlot 38  Single-Family        2013  ...
# 8                        Midtown  Single-Family        2019  ...
# 9               Midtown Elevated  Single-Family        2019  ...
# 10              Midtown Elevated  Single-Family        2019  ...
# 11  Colina Homes/Labranch Street  Single-Family        2017  ...
# 12                Stuart Terrace  Single-Family        2021  ...
# 13                Stuart Terrace  Single-Family        2021  ...
# 14                   Fairgrounds  Single-Family        1999  ...
# 15                      Montrose  Single-Family        2014  ...
# 16                   Fairgrounds  Single-Family        2005  ...
# 17                  Drew Gardens  Single-Family        2006  ...
# 18               Skyline/Midtown  Single-Family        2015  ...
# 19                      Runnells  Single-Family        1900  ...
# 20                 Enclave/Robin  Single-Family        2015  ...
# 21         Allen Pines Lofts Sub  Single-Family        2020  ...
# 22         Allen Pines Lofts Sub  Single-Family        2020  ...
# 23         Allen Pines Lofts Sub  Single-Family        2020  ...
# 24                Baker W R Ssbb  Single-Family        2020  ...
# 25           Austin Hadley Place  Single-Family        2007  ...
# 26           Austin Hadley Place  Single-Family        2007  ...
# 27                      Montrose  Single-Family        1920  ...
# 28              COURTLANDT PLACE  Single-Family        1910  ...
#
#                                style  list_price  market_area  \
# 0                Contemporary/Modern      445000           16
# 1                      Mediterranean      489000           16
# 2                Contemporary/Modern      429000           16
# 3                Contemporary/Modern      439000           16
# 4   Contemporary/Modern, Traditional      404000           16
# 5                        Traditional      429000           16
# 6                        Traditional      320000           16
# 7         Mediterranean, Traditional     1075000           16
# 8                Contemporary/Modern      609900           16
# 9                        Traditional      629900           16
# 10                       Traditional      534800           16
# 11               Contemporary/Modern      539000           16
# 12               Contemporary/Modern      996075           16
# 13               Contemporary/Modern      936925           16
# 14               Contemporary/Modern      485000           16
# 15                       Traditional      520000           16
# 16                       Traditional     1120000           16
# 17               Contemporary/Modern      496500           16
# 18               Contemporary/Modern      500000           16
# 19                       Traditional      995000           16
# 20                     Mediterranean      475000           16
# 21               Contemporary/Modern      525000           16
# 22               Contemporary/Modern      525000           16
# 23               Contemporary/Modern      525000           16
# 24               Contemporary/Modern      699900           16
# 25                       Traditional      450000           16
# 26               Contemporary/Modern      499000           16
# 27                       Traditional      585000           16
# 28          Other Style, Traditional     3250000           16
#
#                  area  dom  cdom   list_date  school_district  \
# 0   Midtown - Houston  150   150    9/9/2020      HOUSTON ISD
# 1   Midtown - Houston   30    30    1/7/2021      HOUSTON ISD
# 2   Midtown - Houston  135   135   9/24/2020      HOUSTON ISD
# 3   Midtown - Houston  135   135   9/24/2020      HOUSTON ISD
# 4   Midtown - Houston   36    36    1/1/2021      HOUSTON ISD
# 5   Midtown - Houston    5    45    2/1/2021      HOUSTON ISD
# 6   Midtown - Houston   20    20  11/16/2020      HOUSTON ISD
# 7   Midtown - Houston   59   423   12/9/2020      HOUSTON ISD
# 8   Midtown - Houston   66   485   12/2/2020      HOUSTON ISD
# 9   Midtown - Houston   12   962   1/25/2021      HOUSTON ISD
# 10  Midtown - Houston   12   962   1/25/2021      HOUSTON ISD
# 11  Midtown - Houston   95    95   11/3/2020      HOUSTON ISD
# 12  Midtown - Houston   80    80  11/18/2020      HOUSTON ISD
# 13  Midtown - Houston   80    80  11/18/2020      HOUSTON ISD
# 14  Midtown - Houston   75    75  11/23/2020      HOUSTON ISD
# 15  Midtown - Houston  125   125   10/4/2020      HOUSTON ISD
# 16  Midtown - Houston   75   161  11/23/2020      HOUSTON ISD
# 17  Midtown - Houston  236   236   6/15/2020      HOUSTON ISD
# 18  Midtown - Houston   32   155    1/5/2021      HOUSTON ISD
# 19  Midtown - Houston  216   216    7/5/2020      HOUSTON ISD
# 20  Midtown - Houston   21    21   1/16/2021      HOUSTON ISD
# 21  Midtown - Houston   97   314   11/1/2020      HOUSTON ISD
# 22  Midtown - Houston  109   109  10/20/2020      HOUSTON ISD
# 23  Midtown - Houston  109   109  10/20/2020      HOUSTON ISD
# 24  Midtown - Houston   47    47   11/6/2020      HOUSTON ISD
# 25  Midtown - Houston   64    64   12/4/2020      HOUSTON ISD
# 26  Midtown - Houston   17   109   1/20/2021      HOUSTON ISD
# 27           Montrose   25    25   1/12/2021      HOUSTON ISD
# 28           Montrose   80   242  11/18/2020      HOUSTON ISD
#
#                            elementary          high_school
# 0              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 1              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 2              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 3              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 4              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 5              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 6              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 7              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 8              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 9              GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 10             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 11             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 12             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 13             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 14             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 15  WHARTON K-8 DUAL LANGUAGE ACADEMY    LAMAR HIGH SCHOOL
# 16             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 17             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 18             GREGORY-LINCOLN ED CTR  HEIGHTS HIGH SCHOOL
# 19             GREGORY-LINCOLN ED CTR  HEIGHTS HIGH SCHOOL
# 20             GREGORY-LINCOLN ED CTR  HEIGHTS HIGH SCHOOL
# 21             GREGORY-LINCOLN ED CTR  HEIGHTS HIGH SCHOOL
# 22             GREGORY-LINCOLN ED CTR  HEIGHTS HIGH SCHOOL
# 23             GREGORY-LINCOLN ED CTR  HEIGHTS HIGH SCHOOL
# 24             GREGORY-LINCOLN ED CTR  HEIGHTS HIGH SCHOOL
# 25             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 26             GREGORY-LINCOLN ED CTR    LAMAR HIGH SCHOOL
# 27                       MACGREGOR EL    LAMAR HIGH SCHOOL
# 28                       MACGREGOR EL    LAMAR HIGH SCHOOL
#
# [29 rows x 29 columns]

# %%
# replace high school with h s to match TEA table
customer_data_df = raw_har1_df.replace({"high_school" :"HIGH SCHOOL"}, "H S", regex = True)
customer_data_df
# Out:
#          mls  street_number       street_name  unit     city    zip  county  \
# 0   90227486           2403     Austin Street   NaN  Houston  77004  Harris
# 1   76269817           3123     Austin Street   NaN  Houston  77004  Harris
# 2   44013547           3108   Crawford Street   NaN  Houston  77004  Harris
# 3   78420188           3110   Crawford Street   NaN  Houston  77004  Harris
# 4   32279965           1804     Dennis Street   NaN  Houston  77004  Harris
# 5   12892280           1411      Elgin Street   NaN  Houston  77004  Harris
# 6   47688089           1527    FRANCIS Street   NaN  Houston  77004  Harris
# 7   14702643           1611     Holman Street   NaN  Houston  77004  Harris
# 8   23353569           1713     Holman Street   NaN  Houston  77004  Harris
# 9   95756492           1315   Isabella Street   NaN  Houston  77004  Harris
# 10  52061919           1319   Isabella Street   NaN  Houston  77004  Harris
# 11  13938486           3203  La Branch Street   NaN  Houston  77004  Harris
# 12  77592370           1503     Stuart Street   NaN  Houston  77004  Harris
# 13  87702589           1505     Stuart Street   NaN  Houston  77004  Harris
# 14   8797838            504      Anita Street   NaN  Houston  77006  Harris
# 15  43111391            227   Avondale Street   NaN  Houston  77006  Harris
# 16  59046521            302     Dennis Street   NaN  Houston  77006  Harris
# 17  29513112            124       Drew Street   NaN  Houston  77006  Harris
# 18  82691736           1004  Cleveland Street   NaN  Houston  77019  Harris
# 19  13863906           1106      Oneil Street   NaN  Houston  77019  Harris
# 20  71466098           1112      Robin Street   NaN  Houston  77019  Harris
# 21  95801397           1504   Saulnier Street   NaN  Houston  77019  Harris
# 22  49786342           1506   Saulnier Street   NaN  Houston  77019  Harris
# 23  89590051           1508   Saulnier Street   NaN  Houston  77019  Harris
# 24  49821838           1610     Victor Street   NaN  Houston  77019  Harris
# 25  67264587           1314         Hadley St   NaN  Houston  77002  Harris
# 26  21315276           1316         Hadley St   NaN  Houston  77002  Harris
# 27  11725906           3405     Audubon Place   NaN  Houston  77006  Harris
# 28  56775365              4  Courtlandt Place   NaN  Houston  77006  Harris
#
#                      subdivision      home_type  year_built  ...  \
# 0                 Austin Skyline  Single-Family        2015  ...
# 1      Montione Vls/Elgin Pt Rep  Single-Family        2014  ...
# 2                        Midtown  Single-Family           0  ...
# 3                        Midtown  Single-Family           0  ...
# 4            Weekley at Chenvert  Single-Family        2014  ...
# 5      Montione Vls/Elgin Pt Rep  Single-Family        2014  ...
# 6                FRANCIS STATION  Single-Family        2000  ...
# 7               Holman Outlot 38  Single-Family        2013  ...
# 8                        Midtown  Single-Family        2019  ...
# 9               Midtown Elevated  Single-Family        2019  ...
# 10              Midtown Elevated  Single-Family        2019  ...
# 11  Colina Homes/Labranch Street  Single-Family        2017  ...
# 12                Stuart Terrace  Single-Family        2021  ...
# 13                Stuart Terrace  Single-Family        2021  ...
# 14                   Fairgrounds  Single-Family        1999  ...
# 15                      Montrose  Single-Family        2014  ...
# 16                   Fairgrounds  Single-Family        2005  ...
# 17                  Drew Gardens  Single-Family        2006  ...
# 18               Skyline/Midtown  Single-Family        2015  ...
# 19                      Runnells  Single-Family        1900  ...
# 20                 Enclave/Robin  Single-Family        2015  ...
# 21         Allen Pines Lofts Sub  Single-Family        2020  ...
# 22         Allen Pines Lofts Sub  Single-Family        2020  ...
# 23         Allen Pines Lofts Sub  Single-Family        2020  ...
# 24                Baker W R Ssbb  Single-Family        2020  ...
# 25           Austin Hadley Place  Single-Family        2007  ...
# 26           Austin Hadley Place  Single-Family        2007  ...
# 27                      Montrose  Single-Family        1920  ...
# 28              COURTLANDT PLACE  Single-Family        1910  ...
#
#                                style  list_price  market_area  \
# 0                Contemporary/Modern      445000           16
# 1                      Mediterranean      489000           16
# 2                Contemporary/Modern      429000           16
# 3                Contemporary/Modern      439000           16
# 4   Contemporary/Modern, Traditional      404000           16
# 5                        Traditional      429000           16
# 6                        Traditional      320000           16
# 7         Mediterranean, Traditional     1075000           16
# 8                Contemporary/Modern      609900           16
# 9                        Traditional      629900           16
# 10                       Traditional      534800           16
# 11               Contemporary/Modern      539000           16
# 12               Contemporary/Modern      996075           16
# 13               Contemporary/Modern      936925           16
# 14               Contemporary/Modern      485000           16
# 15                       Traditional      520000           16
# 16                       Traditional     1120000           16
# 17               Contemporary/Modern      496500           16
# 18               Contemporary/Modern      500000           16
# 19                       Traditional      995000           16
# 20                     Mediterranean      475000           16
# 21               Contemporary/Modern      525000           16
# 22               Contemporary/Modern      525000           16
# 23               Contemporary/Modern      525000           16
# 24               Contemporary/Modern      699900           16
# 25                       Traditional      450000           16
# 26               Contemporary/Modern      499000           16
# 27                       Traditional      585000           16
# 28          Other Style, Traditional     3250000           16
#
#                  area  dom  cdom   list_date  school_district  \
# 0   Midtown - Houston  150   150    9/9/2020      HOUSTON ISD
# 1   Midtown - Houston   30    30    1/7/2021      HOUSTON ISD
# 2   Midtown - Houston  135   135   9/24/2020      HOUSTON ISD
# 3   Midtown - Houston  135   135   9/24/2020      HOUSTON ISD
# 4   Midtown - Houston   36    36    1/1/2021      HOUSTON ISD
# 5   Midtown - Houston    5    45    2/1/2021      HOUSTON ISD
# 6   Midtown - Houston   20    20  11/16/2020      HOUSTON ISD
# 7   Midtown - Houston   59   423   12/9/2020      HOUSTON ISD
# 8   Midtown - Houston   66   485   12/2/2020      HOUSTON ISD
# 9   Midtown - Houston   12   962   1/25/2021      HOUSTON ISD
# 10  Midtown - Houston   12   962   1/25/2021      HOUSTON ISD
# 11  Midtown - Houston   95    95   11/3/2020      HOUSTON ISD
# 12  Midtown - Houston   80    80  11/18/2020      HOUSTON ISD
# 13  Midtown - Houston   80    80  11/18/2020      HOUSTON ISD
# 14  Midtown - Houston   75    75  11/23/2020      HOUSTON ISD
# 15  Midtown - Houston  125   125   10/4/2020      HOUSTON ISD
# 16  Midtown - Houston   75   161  11/23/2020      HOUSTON ISD
# 17  Midtown - Houston  236   236   6/15/2020      HOUSTON ISD
# 18  Midtown - Houston   32   155    1/5/2021      HOUSTON ISD
# 19  Midtown - Houston  216   216    7/5/2020      HOUSTON ISD
# 20  Midtown - Houston   21    21   1/16/2021      HOUSTON ISD
# 21  Midtown - Houston   97   314   11/1/2020      HOUSTON ISD
# 22  Midtown - Houston  109   109  10/20/2020      HOUSTON ISD
# 23  Midtown - Houston  109   109  10/20/2020      HOUSTON ISD
# 24  Midtown - Houston   47    47   11/6/2020      HOUSTON ISD
# 25  Midtown - Houston   64    64   12/4/2020      HOUSTON ISD
# 26  Midtown - Houston   17   109   1/20/2021      HOUSTON ISD
# 27           Montrose   25    25   1/12/2021      HOUSTON ISD
# 28           Montrose   80   242  11/18/2020      HOUSTON ISD
#
#                            elementary  high_school
# 0              GREGORY-LINCOLN ED CTR    LAMAR H S
# 1              GREGORY-LINCOLN ED CTR    LAMAR H S
# 2              GREGORY-LINCOLN ED CTR    LAMAR H S
# 3              GREGORY-LINCOLN ED CTR    LAMAR H S
# 4              GREGORY-LINCOLN ED CTR    LAMAR H S
# 5              GREGORY-LINCOLN ED CTR    LAMAR H S
# 6              GREGORY-LINCOLN ED CTR    LAMAR H S
# 7              GREGORY-LINCOLN ED CTR    LAMAR H S
# 8              GREGORY-LINCOLN ED CTR    LAMAR H S
# 9              GREGORY-LINCOLN ED CTR    LAMAR H S
# 10             GREGORY-LINCOLN ED CTR    LAMAR H S
# 11             GREGORY-LINCOLN ED CTR    LAMAR H S
# 12             GREGORY-LINCOLN ED CTR    LAMAR H S
# 13             GREGORY-LINCOLN ED CTR    LAMAR H S
# 14             GREGORY-LINCOLN ED CTR    LAMAR H S
# 15  WHARTON K-8 DUAL LANGUAGE ACADEMY    LAMAR H S
# 16             GREGORY-LINCOLN ED CTR    LAMAR H S
# 17             GREGORY-LINCOLN ED CTR    LAMAR H S
# 18             GREGORY-LINCOLN ED CTR  HEIGHTS H S
# 19             GREGORY-LINCOLN ED CTR  HEIGHTS H S
# 20             GREGORY-LINCOLN ED CTR  HEIGHTS H S
# 21             GREGORY-LINCOLN ED CTR  HEIGHTS H S
# 22             GREGORY-LINCOLN ED CTR  HEIGHTS H S
# 23             GREGORY-LINCOLN ED CTR  HEIGHTS H S
# 24             GREGORY-LINCOLN ED CTR  HEIGHTS H S
# 25             GREGORY-LINCOLN ED CTR    LAMAR H S
# 26             GREGORY-LINCOLN ED CTR    LAMAR H S
# 27                       MACGREGOR EL    LAMAR H S
# 28                       MACGREGOR EL    LAMAR H S
#
# [29 rows x 29 columns]

# %%
# Total info
customer_data_df.shape
# Out:
# (29, 29)

# %%
# Columns list
customer_data_df.columns
# Out:
# Index(['mls', 'street_number', 'street_name', 'unit', 'city', 'zip', 'county',
#        'subdivision', 'home_type', 'year_built', 'bedrooms', 'full_baths',
#        'half_baths', 'total_baths', 'room_count', 'fireplaces', 'stories',
#        'pool_private', 'garages', 'style', 'list_price', 'market_area', 'area',
#        'dom', 'cdom', 'list_date', 'school_district', 'elementary',
#        'high_school'],
#       dtype='object')

# %%
# Navigate a single column
customer_data_df['city']
# Out:
# 0     Houston
# 1     Houston
# 2     Houston
# 3     Houston
# 4     Houston
# 5     Houston
# 6     Houston
# 7     Houston
# 8     Houston
# 9     Houston
# 10    Houston
# 11    Houston
# 12    Houston
# 13    Houston
# 14    Houston
# 15    Houston
# 16    Houston
# 17    Houston
# 18    Houston
# 19    Houston
# 20    Houston
# 21    Houston
# 22    Houston
# 23    Houston
# 24    Houston
# 25    Houston
# 26    Houston
# 27    Houston
# 28    Houston
# Name: city, dtype: object

# %%
# Replace null values with "0"
# customer_data_df['fireplaces']= customer_data_df['fireplaces'].fillna(0)

# %%
# Check replacement
# customer_data_df['fireplaces']

# %%
# Replace null values with "0"
# customer_data_df['garages']= customer_data_df['garages'].fillna(0)

# %%
# Checking unique values
# customer_data_df.nunique()

# %%
# Checking unique values
customer_data_df.nunique().count()
# Out:
# 29

# %%
# isna/isnull
# customer_data_df.isna().sum()

# %%
# Data types
# customer_data_df.dtypes

# %%
# Create new df
HAR_df= customer_data_df
HAR_df
# Out:
#          mls  street_number       street_name  unit     city    zip  county  \
# 0   90227486           2403     Austin Street   NaN  Houston  77004  Harris
# 1   76269817           3123     Austin Street   NaN  Houston  77004  Harris
# 2   44013547           3108   Crawford Street   NaN  Houston  77004  Harris
# 3   78420188           3110   Crawford Street   NaN  Houston  77004  Harris
# 4   32279965           1804     Dennis Street   NaN  Houston  77004  Harris
# 5   12892280           1411      Elgin Street   NaN  Houston  77004  Harris
# 6   47688089           1527    FRANCIS Street   NaN  Houston  77004  Harris
# 7   14702643           1611     Holman Street   NaN  Houston  77004  Harris
# 8   23353569           1713     Holman Street   NaN  Houston  77004  Harris
# 9   95756492           1315   Isabella Street   NaN  Houston  77004  Harris
# 10  52061919           1319   Isabella Street   NaN  Houston  77004  Harris
# 11  13938486           3203  La Branch Street   NaN  Houston  77004  Harris
# 12  77592370           1503     Stuart Street   NaN  Houston  77004  Harris
# 13  87702589           1505     Stuart Street   NaN  Houston  77004  Harris
# 14   8797838            504      Anita Street   NaN  Houston  77006  Harris
# 15  43111391            227   Avondale Street   NaN  Houston  77006  Harris
# 16  59046521            302     Dennis Street   NaN  Houston  77006  Harris
# 17  29513112            124       Drew Street   NaN  Houston  77006  Harris
# 18  82691736           1004  Cleveland Street   NaN  Houston  77019  Harris
# 19  13863906           1106      Oneil Street   NaN  Houston  77019  Harris
# 20  71466098           1112      Robin Street   NaN  Houston  77019  Harris
# 21  95801397           1504   Saulnier Street   NaN  Houston  77019  Harris
# 22  49786342           1506   Saulnier Street   NaN  Houston  77019  Harris
# 23  89590051           1508   Saulnier Street   NaN  Houston  77019  Harris
# 24  49821838           1610     Victor Street   NaN  Houston  77019  Harris
# 25  67264587           1314         Hadley St   NaN  Houston  77002  Harris
# 26  21315276           1316         Hadley St   NaN  Houston  77002  Harris
# 27  11725906           3405     Audubon Place   NaN  Houston  77006  Harris
# 28  56775365              4  Courtlandt Place   NaN  Houston  77006  Harris
#
#                      subdivision      home_type  year_built  ...  \
# 0                 Austin Skyline  Single-Family        2015  ...
# 1      Montione Vls/Elgin Pt Rep  Single-Family        2014  ...
# 2                        Midtown  Single-Family           0  ...
# 3                        Midtown  Single-Family           0  ...
# 4            Weekley at Chenvert  Single-Family        2014  ...
# 5      Montione Vls/Elgin Pt Rep  Single-Family        2014  ...
# 6                FRANCIS STATION  Single-Family        2000  ...
# 7               Holman Outlot 38  Single-Family        2013  ...
# 8                        Midtown  Single-Family        2019  ...
# 9               Midtown Elevated  Single-Family        2019  ...
# 10              Midtown Elevated  Single-Family        2019  ...
# 11  Colina Homes/Labranch Street  Single-Family        2017  ...
# 12                Stuart Terrace  Single-Family        2021  ...
# 13                Stuart Terrace  Single-Family        2021  ...
# 14                   Fairgrounds  Single-Family        1999  ...
# 15                      Montrose  Single-Family        2014  ...
# 16                   Fairgrounds  Single-Family        2005  ...
# 17                  Drew Gardens  Single-Family        2006  ...
# 18               Skyline/Midtown  Single-Family        2015  ...
# 19                      Runnells  Single-Family        1900  ...
# 20                 Enclave/Robin  Single-Family        2015  ...
# 21         Allen Pines Lofts Sub  Single-Family        2020  ...
# 22         Allen Pines Lofts Sub  Single-Family        2020  ...
# 23         Allen Pines Lofts Sub  Single-Family        2020  ...
# 24                Baker W R Ssbb  Single-Family        2020  ...
# 25           Austin Hadley Place  Single-Family        2007  ...
# 26           Austin Hadley Place  Single-Family        2007  ...
# 27                      Montrose  Single-Family        1920  ...
# 28              COURTLANDT PLACE  Single-Family        1910  ...
#
#                                style  list_price  market_area  \
# 0                Contemporary/Modern      445000           16
# 1                      Mediterranean      489000           16
# 2                Contemporary/Modern      429000           16
# 3                Contemporary/Modern      439000           16
# 4   Contemporary/Modern, Traditional      404000           16
# 5                        Traditional      429000           16
# 6                        Traditional      320000           16
# 7         Mediterranean, Traditional     1075000           16
# 8                Contemporary/Modern      609900           16
# 9                        Traditional      629900           16
# 10                       Traditional      534800           16
# 11               Contemporary/Modern      539000           16
# 12               Contemporary/Modern      996075           16
# 13               Contemporary/Modern      936925           16
# 14               Contemporary/Modern      485000           16
# 15                       Traditional      520000           16
# 16                       Traditional     1120000           16
# 17               Contemporary/Modern      496500           16
# 18               Contemporary/Modern      500000           16
# 19                       Traditional      995000           16
# 20                     Mediterranean      475000           16
# 21               Contemporary/Modern      525000           16
# 22               Contemporary/Modern      525000           16
# 23               Contemporary/Modern      525000           16
# 24               Contemporary/Modern      699900           16
# 25                       Traditional      450000           16
# 26               Contemporary/Modern      499000           16
# 27                       Traditional      585000           16
# 28          Other Style, Traditional     3250000           16
#
#                  area  dom  cdom   list_date  school_district  \
# 0   Midtown - Houston  150   150    9/9/2020      HOUSTON ISD
# 1   Midtown - Houston   30    30    1/7/2021      HOUSTON ISD
# 2   Midtown - Houston  135   135   9/24/2020      HOUSTON ISD
# 3   Midtown - Houston  135   135   9/24/2020      HOUSTON ISD
# 4   Midtown - Houston   36    36    1/1/2021      HOUSTON ISD
# 5   Midtown - Houston    5    45    2/1/2021      HOUSTON ISD
# 6   Midtown - Houston   20    20  11/16/2020      HOUSTON ISD
# 7   Midtown - Houston   59   423   12/9/2020      HOUSTON ISD
# 8   Midtown - Houston   66   485   12/2/2020      HOUSTON ISD
# 9   Midtown - Houston   12   962   1/25/2021      HOUSTON ISD
# 10  Midtown - Houston   12   962   1/25/2021      HOUSTON ISD
# 11  Midtown - Houston   95    95   11/3/2020      HOUSTON ISD
# 12  Midtown - Houston   80    80  11/18/2020      HOUSTON ISD
# 13  Midtown - Houston   80    80  11/18/2020      HOUSTON ISD
# 14  Midtown - Houston   75    75  11/23/2020      HOUSTON ISD
# 15  Midtown - Houston  125   125   10/4/2020      HOUSTON ISD
# 16  Midtown - Houston   75   161  11/23/2020      HOUSTON ISD
# 17  Midtown - Houston  236   236   6/15/2020      HOUSTON ISD
# 18  Midtown - Houston   32   155    1/5/2021      HOUSTON ISD
# 19  Midtown - Houston  216   216    7/5/2020      HOUSTON ISD
# 20  Midtown - Houston   21    21   1/16/2021      HOUSTON ISD
# 21  Midtown - Houston   97   314   11/1/2020      HOUSTON ISD
# 22  Midtown - Houston  109   109  10/20/2020      HOUSTON ISD
# 23  Midtown - Houston  109   109  10/20/2020      HOUSTON ISD
# 24  Midtown - Houston   47    47   11/6/2020      HOUSTON ISD
# 25  Midtown - Houston   64    64   12/4/2020      HOUSTON ISD
# 26  Midtown - Houston   17   109   1/20/2021      HOUSTON ISD
# 27           Montrose   25    25   1/12/2021      HOUSTON ISD
# 28           Montrose   80   242  11/18/2020      HOUSTON ISD
#
#                            elementary  high_school
# 0              GREGORY-LINCOLN ED CTR    LAMAR H S
# 1              GREGORY-LINCOLN ED CTR    LAMAR H S
# 2              GREGORY-LINCOLN ED CTR    LAMAR H S
# 3              GREGORY-LINCOLN ED CTR    LAMAR H S
# 4              GREGORY-LINCOLN ED CTR    LAMAR H S
# 5              GREGORY-LINCOLN ED CTR    LAMAR H S
# 6              GREGORY-LINCOLN ED CTR    LAMAR H S
# 7              GREGORY-LINCOLN ED CTR    LAMAR H S
# 8              GREGORY-LINCOLN ED CTR    LAMAR H S
# 9              GREGORY-LINCOLN ED CTR    LAMAR H S
# 10             GREGORY-LINCOLN ED CTR    LAMAR H S
# 11             GREGORY-LINCOLN ED CTR    LAMAR H S
# 12             GREGORY-LINCOLN ED CTR    LAMAR H S
# 13             GREGORY-LINCOLN ED CTR    LAMAR H S
# 14             GREGORY-LINCOLN ED CTR    LAMAR H S
# 15  WHARTON K-8 DUAL LANGUAGE ACADEMY    LAMAR H S
# 16             GREGORY-LINCOLN ED CTR    LAMAR H S
# 17             GREGORY-LINCOLN ED CTR    LAMAR H S
# 18             GREGORY-LINCOLN ED CTR  HEIGHTS H S
# 19             GREGORY-LINCOLN ED CTR  HEIGHTS H S
# 20             GREGORY-LINCOLN ED CTR  HEIGHTS H S
# 21             GREGORY-LINCOLN ED CTR  HEIGHTS H S
# 22             GREGORY-LINCOLN ED CTR  HEIGHTS H S
# 23             GREGORY-LINCOLN ED CTR  HEIGHTS H S
# 24             GREGORY-LINCOLN ED CTR  HEIGHTS H S
# 25             GREGORY-LINCOLN ED CTR    LAMAR H S
# 26             GREGORY-LINCOLN ED CTR    LAMAR H S
# 27                       MACGREGOR EL    LAMAR H S
# 28                       MACGREGOR EL    LAMAR H S
#
# [29 rows x 29 columns]

# %% [markdown]
# ### Retrieving Latitude and Longitude

# %%
# Creating addresses df
orig_addresses_df = HAR_df[['mls','street_number','street_name','city','zip']]
orig_addresses_df.insert(3,'state','Texas')

orig_addresses_df
# Out:
#          mls  street_number       street_name  state     city    zip
# 0   90227486           2403     Austin Street  Texas  Houston  77004
# 1   76269817           3123     Austin Street  Texas  Houston  77004
# 2   44013547           3108   Crawford Street  Texas  Houston  77004
# 3   78420188           3110   Crawford Street  Texas  Houston  77004
# 4   32279965           1804     Dennis Street  Texas  Houston  77004
# 5   12892280           1411      Elgin Street  Texas  Houston  77004
# 6   47688089           1527    FRANCIS Street  Texas  Houston  77004
# 7   14702643           1611     Holman Street  Texas  Houston  77004
# 8   23353569           1713     Holman Street  Texas  Houston  77004
# 9   95756492           1315   Isabella Street  Texas  Houston  77004
# 10  52061919           1319   Isabella Street  Texas  Houston  77004
# 11  13938486           3203  La Branch Street  Texas  Houston  77004
# 12  77592370           1503     Stuart Street  Texas  Houston  77004
# 13  87702589           1505     Stuart Street  Texas  Houston  77004
# 14   8797838            504      Anita Street  Texas  Houston  77006
# 15  43111391            227   Avondale Street  Texas  Houston  77006
# 16  59046521            302     Dennis Street  Texas  Houston  77006
# 17  29513112            124       Drew Street  Texas  Houston  77006
# 18  82691736           1004  Cleveland Street  Texas  Houston  77019
# 19  13863906           1106      Oneil Street  Texas  Houston  77019
# 20  71466098           1112      Robin Street  Texas  Houston  77019
# 21  95801397           1504   Saulnier Street  Texas  Houston  77019
# 22  49786342           1506   Saulnier Street  Texas  Houston  77019
# 23  89590051           1508   Saulnier Street  Texas  Houston  77019
# 24  49821838           1610     Victor Street  Texas  Houston  77019
# 25  67264587           1314         Hadley St  Texas  Houston  77002
# 26  21315276           1316         Hadley St  Texas  Houston  77002
# 27  11725906           3405     Audubon Place  Texas  Houston  77006
# 28  56775365              4  Courtlandt Place  Texas  Houston  77006

# %%
orig_addresses_df['full_address'] = orig_addresses_df['street_number'].map(str)+' '+orig_addresses_df['street_name'].map(str)+', '+orig_addresses_df['city'].map(str)+', '+orig_addresses_df['state'].map(str)+', '+orig_addresses_df['zip'].map(str)
orig_addresses_df
# Out:
# <ipython-input-17-3295fb9f47e2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orig_addresses_df['full_address'] = orig_addresses_df['street_number'].map(str)+' '+orig_addresses_df['street_name'].map(str)+', '+orig_addresses_df['city'].map(str)+', '+orig_addresses_df['state'].map(str)+', '+orig_addresses_df['zip'].map(str)
#          mls  street_number       street_name  state     city    zip  \
# 0   90227486           2403     Austin Street  Texas  Houston  77004
# 1   76269817           3123     Austin Street  Texas  Houston  77004
# 2   44013547           3108   Crawford Street  Texas  Houston  77004
# 3   78420188           3110   Crawford Street  Texas  Houston  77004
# 4   32279965           1804     Dennis Street  Texas  Houston  77004
# 5   12892280           1411      Elgin Street  Texas  Houston  77004
# 6   47688089           1527    FRANCIS Street  Texas  Houston  77004
# 7   14702643           1611     Holman Street  Texas  Houston  77004
# 8   23353569           1713     Holman Street  Texas  Houston  77004
# 9   95756492           1315   Isabella Street  Texas  Houston  77004
# 10  52061919           1319   Isabella Street  Texas  Houston  77004
# 11  13938486           3203  La Branch Street  Texas  Houston  77004
# 12  77592370           1503     Stuart Street  Texas  Houston  77004
# 13  87702589           1505     Stuart Street  Texas  Houston  77004
# 14   8797838            504      Anita Street  Texas  Houston  77006
# 15  43111391            227   Avondale Street  Texas  Houston  77006
# 16  59046521            302     Dennis Street  Texas  Houston  77006
# 17  29513112            124       Drew Street  Texas  Houston  77006
# 18  82691736           1004  Cleveland Street  Texas  Houston  77019
# 19  13863906           1106      Oneil Street  Texas  Houston  77019
# 20  71466098           1112      Robin Street  Texas  Houston  77019
# 21  95801397           1504   Saulnier Street  Texas  Houston  77019
# 22  49786342           1506   Saulnier Street  Texas  Houston  77019
# 23  89590051           1508   Saulnier Street  Texas  Houston  77019
# 24  49821838           1610     Victor Street  Texas  Houston  77019
# 25  67264587           1314         Hadley St  Texas  Houston  77002
# 26  21315276           1316         Hadley St  Texas  Houston  77002
# 27  11725906           3405     Audubon Place  Texas  Houston  77006
# 28  56775365              4  Courtlandt Place  Texas  Houston  77006
#
#                                     full_address
# 0      2403 Austin Street, Houston, Texas, 77004
# 1      3123 Austin Street, Houston, Texas, 77004
# 2    3108 Crawford Street, Houston, Texas, 77004
# 3    3110 Crawford Street, Houston, Texas, 77004
# 4      1804 Dennis Street, Houston, Texas, 77004
# 5       1411 Elgin Street, Houston, Texas, 77004
# 6     1527 FRANCIS Street, Houston, Texas, 77004
# 7      1611 Holman Street, Houston, Texas, 77004
# 8      1713 Holman Street, Houston, Texas, 77004
# 9    1315 Isabella Street, Houston, Texas, 77004
# 10   1319 Isabella Street, Houston, Texas, 77004
# 11  3203 La Branch Street, Houston, Texas, 77004
# 12     1503 Stuart Street, Houston, Texas, 77004
# 13     1505 Stuart Street, Houston, Texas, 77004
# 14       504 Anita Street, Houston, Texas, 77006
# 15    227 Avondale Street, Houston, Texas, 77006
# 16      302 Dennis Street, Houston, Texas, 77006
# 17        124 Drew Street, Houston, Texas, 77006
# 18  1004 Cleveland Street, Houston, Texas, 77019
# 19      1106 Oneil Street, Houston, Texas, 77019
# 20      1112 Robin Street, Houston, Texas, 77019
# 21   1504 Saulnier Street, Houston, Texas, 77019
# 22   1506 Saulnier Street, Houston, Texas, 77019
# 23   1508 Saulnier Street, Houston, Texas, 77019
# 24     1610 Victor Street, Houston, Texas, 77019
# 25         1314 Hadley St, Houston, Texas, 77002
# 26         1316 Hadley St, Houston, Texas, 77002
# 27     3405 Audubon Place, Houston, Texas, 77006
# 28     4 Courtlandt Place, Houston, Texas, 77006

# %%
addresses_df = orig_addresses_df.drop(['street_number','street_name','city','state','zip'], axis =1)
addresses_df
# Out:
#          mls                                  full_address
# 0   90227486     2403 Austin Street, Houston, Texas, 77004
# 1   76269817     3123 Austin Street, Houston, Texas, 77004
# 2   44013547   3108 Crawford Street, Houston, Texas, 77004
# 3   78420188   3110 Crawford Street, Houston, Texas, 77004
# 4   32279965     1804 Dennis Street, Houston, Texas, 77004
# 5   12892280      1411 Elgin Street, Houston, Texas, 77004
# 6   47688089    1527 FRANCIS Street, Houston, Texas, 77004
# 7   14702643     1611 Holman Street, Houston, Texas, 77004
# 8   23353569     1713 Holman Street, Houston, Texas, 77004
# 9   95756492   1315 Isabella Street, Houston, Texas, 77004
# 10  52061919   1319 Isabella Street, Houston, Texas, 77004
# 11  13938486  3203 La Branch Street, Houston, Texas, 77004
# 12  77592370     1503 Stuart Street, Houston, Texas, 77004
# 13  87702589     1505 Stuart Street, Houston, Texas, 77004
# 14   8797838       504 Anita Street, Houston, Texas, 77006
# 15  43111391    227 Avondale Street, Houston, Texas, 77006
# 16  59046521      302 Dennis Street, Houston, Texas, 77006
# 17  29513112        124 Drew Street, Houston, Texas, 77006
# 18  82691736  1004 Cleveland Street, Houston, Texas, 77019
# 19  13863906      1106 Oneil Street, Houston, Texas, 77019
# 20  71466098      1112 Robin Street, Houston, Texas, 77019
# 21  95801397   1504 Saulnier Street, Houston, Texas, 77019
# 22  49786342   1506 Saulnier Street, Houston, Texas, 77019
# 23  89590051   1508 Saulnier Street, Houston, Texas, 77019
# 24  49821838     1610 Victor Street, Houston, Texas, 77019
# 25  67264587         1314 Hadley St, Houston, Texas, 77002
# 26  21315276         1316 Hadley St, Houston, Texas, 77002
# 27  11725906     3405 Audubon Place, Houston, Texas, 77006
# 28  56775365     4 Courtlandt Place, Houston, Texas, 77006

# %%
#https://towardsdatascience.com/how-to-generate-lat-and-long-coordinates-from-an-address-column-using-pandas-and-googlemaps-api-d66b2720248d
#conda install -c conda-forge gmaps
#conda install -c conda-forge googlemaps
#from googlemaps import Client as GoogleMaps
#from secrets import API_KEY

#gmaps = GoogleMaps('AIzaSyCPvDQ8q0r9qDifnmkcAxxINp8yOUJHSKc')

#addresses = addresses_df['full_address']
#addresses_df

# %%
#import time  #to add delay in case of large DFs, python function

#addresses_df['long'] = ""
# addresses_df['lat'] = ""

# for x in range(len(addresses_df)):
#     try:
#         time.sleep(.5) #to add delay in case of large DFs
#         geocode_result = gmaps.geocode(addresses_df['full_address'][x])
#         addresses_df['lat'][x] = geocode_result[0]['geometry']['location'] ['lat']
#         addresses_df['long'][x] = geocode_result[0]['geometry']['location']['lng']
#     except IndexError:
#         print("Address was wrong...")
#     except Exception as e:
#         print("Unexpected error occurred.", e )
        
# addresses_df.head()
# addresses.to_csv('address_coords.csv')

# %%
# from functools import partial
# from geopy.geocoders import Nominatim

# #2618 Texas St, Houston, Texas, 77003
# geocode = partial(geolocator.geocode, language="en")
# print(geocode("2709 Rosalie Avenue, Houston, Texas, 77004"))
# print(geocode("2709 Rosalie Avenue, Houston"))

# %%
# Dependencies

#https://geopy.readthedocs.io/en/latest/#specifying-parameters-once
#conda install -c conda-forge geopy
#conda install -c conda-forge tqdm
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
#from tqdm import tqdm

# %%
# Example code
# df = pd.DataFrame({'name': ['paris', 'berlin', 'london']})

# geolocator = Nominatim(user_agent="team5")

# from geopy.extra.rate_limiter import RateLimiter
# geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
# df['location'] = df['name'].apply(geocode)

# df['point'] = df['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# df

# %%
# geolocator = Nominatim(user_agent="team5")

# location = geolocator.geocode("1804 Dennis Street, Houston, Texas, 77004")

# print(location.address)
# print(location.latitude)
# print((location.latitude, location.longitude))

# %%
# geolocator = Nominatim(user_agent="team5")
# geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# addresses['location'] = addresses['full_address'].apply(geocode)

# addresses['point'] = addresses['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# #addresses_df.to_csv('address_coords.csv')
# addresses

# %%
# geolocator = Nominatim(user_agent="team5")

# geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# tqdm.pandas() # Progress bar for geocoding dataframe

# addresses_df['location'] = addresses_df['full_address'].progress_apply(geocode)

# addresses_df['coordinates'] = addresses_df['location'].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
# Dependencies

#https://geopy.readthedocs.io/en/latest/#specifying-parameters-once
#conda install -c conda-forge geopy
#conda install -c conda-forge tqdm
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter


coordinates = []
loc_address = []
lat = []
long = []


geolocator = Nominatim(user_agent="team5")

geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

for full_address in addresses_df['full_address']:
    try:
        inputAddress = full_address
        location = geolocator.geocode(inputAddress, timeout=15)
        coordinates.append((location.latitude, location.longitude))
        loc_address.append(inputAddress)
        lat.append((location.latitude))
        long.append((location.longitude))
    except Exception as e:
        print('Error, skipping address...', e)
 
        
geocodes_df = pd.DataFrame({'full_address':loc_address,'latitude':lat,'longitude':long,'geocode':coordinates})

#geocodes_df.to_csv('geocodes_df.csv')
geocodes_df
# Out:
#                                     full_address   latitude  longitude  \
# 0      2403 Austin Street, Houston, Texas, 77004  29.744217 -95.369796
# 1      3123 Austin Street, Houston, Texas, 77004  29.739923 -95.373199
# 2    3108 Crawford Street, Houston, Texas, 77004  29.739044 -95.371597
# 3    3110 Crawford Street, Houston, Texas, 77004  29.739036 -95.371604
# 4      1804 Dennis Street, Houston, Texas, 77004  29.737758 -95.363639
# 5       1411 Elgin Street, Houston, Texas, 77004  29.734418 -95.365059
# 6     1527 FRANCIS Street, Houston, Texas, 77004  29.737667 -95.373427
# 7      1611 Holman Street, Houston, Texas, 77004  29.736427 -95.372789
# 8      1713 Holman Street, Houston, Texas, 77004  29.736007 -95.372107
# 9    1315 Isabella Street, Houston, Texas, 77004  29.735025 -95.378163
# 10   1319 Isabella Street, Houston, Texas, 77004  29.735010 -95.378137
# 11  3203 La Branch Street, Houston, Texas, 77004  29.738887 -95.372750
# 12     1503 Stuart Street, Houston, Texas, 77004  29.738320 -95.373137
# 13     1505 Stuart Street, Houston, Texas, 77004  29.738313 -95.373124
# 14       504 Anita Street, Houston, Texas, 77006  29.745236 -95.380338
# 15    227 Avondale Street, Houston, Texas, 77006  29.745591 -95.383564
# 16      302 Dennis Street, Houston, Texas, 77006  29.747728 -95.379705
# 17        124 Drew Street, Houston, Texas, 77006  29.748537 -95.382592
# 18  1004 Cleveland Street, Houston, Texas, 77019  29.754628 -95.377951
# 19      1106 Oneil Street, Houston, Texas, 77019  29.752783 -95.378820
# 20      1112 Robin Street, Houston, Texas, 77019  29.756511 -95.378903
# 21   1504 Saulnier Street, Houston, Texas, 77019  29.757109 -95.382392
# 22   1506 Saulnier Street, Houston, Texas, 77019  29.757109 -95.382404
# 23   1508 Saulnier Street, Houston, Texas, 77019  29.757109 -95.382416
# 24     1610 Victor Street, Houston, Texas, 77019  29.753984 -95.383265
# 25         1314 Hadley St, Houston, Texas, 77002  29.745504 -95.369861
# 26         1316 Hadley St, Houston, Texas, 77002  29.745496 -95.369848
# 27     3405 Audubon Place, Houston, Texas, 77006  29.742258 -95.386433
# 28     4 Courtlandt Place, Houston, Texas, 77006  29.743935 -95.382426
#
#                                      geocode
# 0    (29.74421667631317, -95.36979554912456)
# 1   (29.739923346938777, -95.37319902040817)
# 2    (29.73904367346939, -95.37159746938775)
# 3   (29.739035591836736, -95.37160383673469)
# 4                   (29.7377576, -95.363639)
# 5                  (29.7344178, -95.3650585)
# 6    (29.737666836734693, -95.3734274489796)
# 7                    (29.736427, -95.372789)
# 8   (29.736006795918367, -95.37210659183673)
# 9    (29.73502457142857, -95.37816271428572)
# 10  (29.735009591836736, -95.37813691836735)
# 11  (29.738887489795918, -95.37274957142857)
# 12   (29.73832030612245, -95.37313710204081)
# 13  (29.738312612244897, -95.37312420408163)
# 14  (29.745236489795918, -95.38033785714286)
# 15  (29.745590653061225, -95.38356357142857)
# 16                  (29.747728, -95.3797045)
# 17   (29.74853718367347, -95.38259197959184)
# 18   (29.75462787755102, -95.37795148979592)
# 19  (29.752782693877553, -95.37881955102041)
# 20   (29.756511387755104, -95.3789028367347)
# 21   (29.75710942857143, -95.38239153061225)
# 22  (29.757109142857143, -95.38240379591836)
# 23  (29.757108857142857, -95.38241606122449)
# 24   (29.753984306122447, -95.3832651632653)
# 25  (29.745504036147487, -95.36986074136271)
# 26  (29.745496327025702, -95.36984813298596)
# 27   (29.74225848979592, -95.38643271428572)
# 28                 (29.7439349, -95.3824257)

# %%
# Merge to reconnect mls

addresses_df
geocodes_df

coord_df=pd.merge(addresses_df,geocodes_df,on = "full_address")
coord_df
# Out:
#          mls                                  full_address   latitude  \
# 0   90227486     2403 Austin Street, Houston, Texas, 77004  29.744217
# 1   76269817     3123 Austin Street, Houston, Texas, 77004  29.739923
# 2   44013547   3108 Crawford Street, Houston, Texas, 77004  29.739044
# 3   78420188   3110 Crawford Street, Houston, Texas, 77004  29.739036
# 4   32279965     1804 Dennis Street, Houston, Texas, 77004  29.737758
# 5   12892280      1411 Elgin Street, Houston, Texas, 77004  29.734418
# 6   47688089    1527 FRANCIS Street, Houston, Texas, 77004  29.737667
# 7   14702643     1611 Holman Street, Houston, Texas, 77004  29.736427
# 8   23353569     1713 Holman Street, Houston, Texas, 77004  29.736007
# 9   95756492   1315 Isabella Street, Houston, Texas, 77004  29.735025
# 10  52061919   1319 Isabella Street, Houston, Texas, 77004  29.735010
# 11  13938486  3203 La Branch Street, Houston, Texas, 77004  29.738887
# 12  77592370     1503 Stuart Street, Houston, Texas, 77004  29.738320
# 13  87702589     1505 Stuart Street, Houston, Texas, 77004  29.738313
# 14   8797838       504 Anita Street, Houston, Texas, 77006  29.745236
# 15  43111391    227 Avondale Street, Houston, Texas, 77006  29.745591
# 16  59046521      302 Dennis Street, Houston, Texas, 77006  29.747728
# 17  29513112        124 Drew Street, Houston, Texas, 77006  29.748537
# 18  82691736  1004 Cleveland Street, Houston, Texas, 77019  29.754628
# 19  13863906      1106 Oneil Street, Houston, Texas, 77019  29.752783
# 20  71466098      1112 Robin Street, Houston, Texas, 77019  29.756511
# 21  95801397   1504 Saulnier Street, Houston, Texas, 77019  29.757109
# 22  49786342   1506 Saulnier Street, Houston, Texas, 77019  29.757109
# 23  89590051   1508 Saulnier Street, Houston, Texas, 77019  29.757109
# 24  49821838     1610 Victor Street, Houston, Texas, 77019  29.753984
# 25  67264587         1314 Hadley St, Houston, Texas, 77002  29.745504
# 26  21315276         1316 Hadley St, Houston, Texas, 77002  29.745496
# 27  11725906     3405 Audubon Place, Houston, Texas, 77006  29.742258
# 28  56775365     4 Courtlandt Place, Houston, Texas, 77006  29.743935
#
#     longitude                                   geocode
# 0  -95.369796   (29.74421667631317, -95.36979554912456)
# 1  -95.373199  (29.739923346938777, -95.37319902040817)
# 2  -95.371597   (29.73904367346939, -95.37159746938775)
# 3  -95.371604  (29.739035591836736, -95.37160383673469)
# 4  -95.363639                  (29.7377576, -95.363639)
# 5  -95.365059                 (29.7344178, -95.3650585)
# 6  -95.373427   (29.737666836734693, -95.3734274489796)
# 7  -95.372789                   (29.736427, -95.372789)
# 8  -95.372107  (29.736006795918367, -95.37210659183673)
# 9  -95.378163   (29.73502457142857, -95.37816271428572)
# 10 -95.378137  (29.735009591836736, -95.37813691836735)
# 11 -95.372750  (29.738887489795918, -95.37274957142857)
# 12 -95.373137   (29.73832030612245, -95.37313710204081)
# 13 -95.373124  (29.738312612244897, -95.37312420408163)
# 14 -95.380338  (29.745236489795918, -95.38033785714286)
# 15 -95.383564  (29.745590653061225, -95.38356357142857)
# 16 -95.379705                  (29.747728, -95.3797045)
# 17 -95.382592   (29.74853718367347, -95.38259197959184)
# 18 -95.377951   (29.75462787755102, -95.37795148979592)
# 19 -95.378820  (29.752782693877553, -95.37881955102041)
# 20 -95.378903   (29.756511387755104, -95.3789028367347)
# 21 -95.382392   (29.75710942857143, -95.38239153061225)
# 22 -95.382404  (29.757109142857143, -95.38240379591836)
# 23 -95.382416  (29.757108857142857, -95.38241606122449)
# 24 -95.383265   (29.753984306122447, -95.3832651632653)
# 25 -95.369861  (29.745504036147487, -95.36986074136271)
# 26 -95.369848  (29.745496327025702, -95.36984813298596)
# 27 -95.386433   (29.74225848979592, -95.38643271428572)
# 28 -95.382426                 (29.7439349, -95.3824257)

# %%
# Merge to reconnect mls
 

NEW_df=pd.merge(HAR_df,coord_df,on = "mls")
NEW_df
# Out:
#          mls  street_number       street_name  unit     city    zip  county  \
# 0   90227486           2403     Austin Street   NaN  Houston  77004  Harris
# 1   76269817           3123     Austin Street   NaN  Houston  77004  Harris
# 2   44013547           3108   Crawford Street   NaN  Houston  77004  Harris
# 3   78420188           3110   Crawford Street   NaN  Houston  77004  Harris
# 4   32279965           1804     Dennis Street   NaN  Houston  77004  Harris
# 5   12892280           1411      Elgin Street   NaN  Houston  77004  Harris
# 6   47688089           1527    FRANCIS Street   NaN  Houston  77004  Harris
# 7   14702643           1611     Holman Street   NaN  Houston  77004  Harris
# 8   23353569           1713     Holman Street   NaN  Houston  77004  Harris
# 9   95756492           1315   Isabella Street   NaN  Houston  77004  Harris
# 10  52061919           1319   Isabella Street   NaN  Houston  77004  Harris
# 11  13938486           3203  La Branch Street   NaN  Houston  77004  Harris
# 12  77592370           1503     Stuart Street   NaN  Houston  77004  Harris
# 13  87702589           1505     Stuart Street   NaN  Houston  77004  Harris
# 14   8797838            504      Anita Street   NaN  Houston  77006  Harris
# 15  43111391            227   Avondale Street   NaN  Houston  77006  Harris
# 16  59046521            302     Dennis Street   NaN  Houston  77006  Harris
# 17  29513112            124       Drew Street   NaN  Houston  77006  Harris
# 18  82691736           1004  Cleveland Street   NaN  Houston  77019  Harris
# 19  13863906           1106      Oneil Street   NaN  Houston  77019  Harris
# 20  71466098           1112      Robin Street   NaN  Houston  77019  Harris
# 21  95801397           1504   Saulnier Street   NaN  Houston  77019  Harris
# 22  49786342           1506   Saulnier Street   NaN  Houston  77019  Harris
# 23  89590051           1508   Saulnier Street   NaN  Houston  77019  Harris
# 24  49821838           1610     Victor Street   NaN  Houston  77019  Harris
# 25  67264587           1314         Hadley St   NaN  Houston  77002  Harris
# 26  21315276           1316         Hadley St   NaN  Houston  77002  Harris
# 27  11725906           3405     Audubon Place   NaN  Houston  77006  Harris
# 28  56775365              4  Courtlandt Place   NaN  Houston  77006  Harris
#
#                      subdivision      home_type  year_built  ...  dom  cdom  \
# 0                 Austin Skyline  Single-Family        2015  ...  150   150
# 1      Montione Vls/Elgin Pt Rep  Single-Family        2014  ...   30    30
# 2                        Midtown  Single-Family           0  ...  135   135
# 3                        Midtown  Single-Family           0  ...  135   135
# 4            Weekley at Chenvert  Single-Family        2014  ...   36    36
# 5      Montione Vls/Elgin Pt Rep  Single-Family        2014  ...    5    45
# 6                FRANCIS STATION  Single-Family        2000  ...   20    20
# 7               Holman Outlot 38  Single-Family        2013  ...   59   423
# 8                        Midtown  Single-Family        2019  ...   66   485
# 9               Midtown Elevated  Single-Family        2019  ...   12   962
# 10              Midtown Elevated  Single-Family        2019  ...   12   962
# 11  Colina Homes/Labranch Street  Single-Family        2017  ...   95    95
# 12                Stuart Terrace  Single-Family        2021  ...   80    80
# 13                Stuart Terrace  Single-Family        2021  ...   80    80
# 14                   Fairgrounds  Single-Family        1999  ...   75    75
# 15                      Montrose  Single-Family        2014  ...  125   125
# 16                   Fairgrounds  Single-Family        2005  ...   75   161
# 17                  Drew Gardens  Single-Family        2006  ...  236   236
# 18               Skyline/Midtown  Single-Family        2015  ...   32   155
# 19                      Runnells  Single-Family        1900  ...  216   216
# 20                 Enclave/Robin  Single-Family        2015  ...   21    21
# 21         Allen Pines Lofts Sub  Single-Family        2020  ...   97   314
# 22         Allen Pines Lofts Sub  Single-Family        2020  ...  109   109
# 23         Allen Pines Lofts Sub  Single-Family        2020  ...  109   109
# 24                Baker W R Ssbb  Single-Family        2020  ...   47    47
# 25           Austin Hadley Place  Single-Family        2007  ...   64    64
# 26           Austin Hadley Place  Single-Family        2007  ...   17   109
# 27                      Montrose  Single-Family        1920  ...   25    25
# 28              COURTLANDT PLACE  Single-Family        1910  ...   80   242
#
#      list_date  school_district                         elementary  \
# 0     9/9/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 1     1/7/2021      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 2    9/24/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 3    9/24/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 4     1/1/2021      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 5     2/1/2021      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 6   11/16/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 7    12/9/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 8    12/2/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 9    1/25/2021      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 10   1/25/2021      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 11   11/3/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 12  11/18/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 13  11/18/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 14  11/23/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 15   10/4/2020      HOUSTON ISD  WHARTON K-8 DUAL LANGUAGE ACADEMY
# 16  11/23/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 17   6/15/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 18    1/5/2021      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 19    7/5/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 20   1/16/2021      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 21   11/1/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 22  10/20/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 23  10/20/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 24   11/6/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 25   12/4/2020      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 26   1/20/2021      HOUSTON ISD             GREGORY-LINCOLN ED CTR
# 27   1/12/2021      HOUSTON ISD                       MACGREGOR EL
# 28  11/18/2020      HOUSTON ISD                       MACGREGOR EL
#
#     high_school                                  full_address   latitude  \
# 0     LAMAR H S     2403 Austin Street, Houston, Texas, 77004  29.744217
# 1     LAMAR H S     3123 Austin Street, Houston, Texas, 77004  29.739923
# 2     LAMAR H S   3108 Crawford Street, Houston, Texas, 77004  29.739044
# 3     LAMAR H S   3110 Crawford Street, Houston, Texas, 77004  29.739036
# 4     LAMAR H S     1804 Dennis Street, Houston, Texas, 77004  29.737758
# 5     LAMAR H S      1411 Elgin Street, Houston, Texas, 77004  29.734418
# 6     LAMAR H S    1527 FRANCIS Street, Houston, Texas, 77004  29.737667
# 7     LAMAR H S     1611 Holman Street, Houston, Texas, 77004  29.736427
# 8     LAMAR H S     1713 Holman Street, Houston, Texas, 77004  29.736007
# 9     LAMAR H S   1315 Isabella Street, Houston, Texas, 77004  29.735025
# 10    LAMAR H S   1319 Isabella Street, Houston, Texas, 77004  29.735010
# 11    LAMAR H S  3203 La Branch Street, Houston, Texas, 77004  29.738887
# 12    LAMAR H S     1503 Stuart Street, Houston, Texas, 77004  29.738320
# 13    LAMAR H S     1505 Stuart Street, Houston, Texas, 77004  29.738313
# 14    LAMAR H S       504 Anita Street, Houston, Texas, 77006  29.745236
# 15    LAMAR H S    227 Avondale Street, Houston, Texas, 77006  29.745591
# 16    LAMAR H S      302 Dennis Street, Houston, Texas, 77006  29.747728
# 17    LAMAR H S        124 Drew Street, Houston, Texas, 77006  29.748537
# 18  HEIGHTS H S  1004 Cleveland Street, Houston, Texas, 77019  29.754628
# 19  HEIGHTS H S      1106 Oneil Street, Houston, Texas, 77019  29.752783
# 20  HEIGHTS H S      1112 Robin Street, Houston, Texas, 77019  29.756511
# 21  HEIGHTS H S   1504 Saulnier Street, Houston, Texas, 77019  29.757109
# 22  HEIGHTS H S   1506 Saulnier Street, Houston, Texas, 77019  29.757109
# 23  HEIGHTS H S   1508 Saulnier Street, Houston, Texas, 77019  29.757109
# 24  HEIGHTS H S     1610 Victor Street, Houston, Texas, 77019  29.753984
# 25    LAMAR H S         1314 Hadley St, Houston, Texas, 77002  29.745504
# 26    LAMAR H S         1316 Hadley St, Houston, Texas, 77002  29.745496
# 27    LAMAR H S     3405 Audubon Place, Houston, Texas, 77006  29.742258
# 28    LAMAR H S     4 Courtlandt Place, Houston, Texas, 77006  29.743935
#
#     longitude                                   geocode
# 0  -95.369796   (29.74421667631317, -95.36979554912456)
# 1  -95.373199  (29.739923346938777, -95.37319902040817)
# 2  -95.371597   (29.73904367346939, -95.37159746938775)
# 3  -95.371604  (29.739035591836736, -95.37160383673469)
# 4  -95.363639                  (29.7377576, -95.363639)
# 5  -95.365059                 (29.7344178, -95.3650585)
# 6  -95.373427   (29.737666836734693, -95.3734274489796)
# 7  -95.372789                   (29.736427, -95.372789)
# 8  -95.372107  (29.736006795918367, -95.37210659183673)
# 9  -95.378163   (29.73502457142857, -95.37816271428572)
# 10 -95.378137  (29.735009591836736, -95.37813691836735)
# 11 -95.372750  (29.738887489795918, -95.37274957142857)
# 12 -95.373137   (29.73832030612245, -95.37313710204081)
# 13 -95.373124  (29.738312612244897, -95.37312420408163)
# 14 -95.380338  (29.745236489795918, -95.38033785714286)
# 15 -95.383564  (29.745590653061225, -95.38356357142857)
# 16 -95.379705                  (29.747728, -95.3797045)
# 17 -95.382592   (29.74853718367347, -95.38259197959184)
# 18 -95.377951   (29.75462787755102, -95.37795148979592)
# 19 -95.378820  (29.752782693877553, -95.37881955102041)
# 20 -95.378903   (29.756511387755104, -95.3789028367347)
# 21 -95.382392   (29.75710942857143, -95.38239153061225)
# 22 -95.382404  (29.757109142857143, -95.38240379591836)
# 23 -95.382416  (29.757108857142857, -95.38241606122449)
# 24 -95.383265   (29.753984306122447, -95.3832651632653)
# 25 -95.369861  (29.745504036147487, -95.36986074136271)
# 26 -95.369848  (29.745496327025702, -95.36984813298596)
# 27 -95.386433   (29.74225848979592, -95.38643271428572)
# 28 -95.382426                 (29.7439349, -95.3824257)
#
# [29 rows x 33 columns]

# %% [markdown]
# ### School Dataframes

# %%
# Writing to clean csv
HAR_df.to_csv("../Resources/alt_clean_har.csv", index = False)

# %%
# creating elementary school potion of junction table
raw_mls_el_df = HAR_df[['mls','elementary']]
mls_el_df= raw_mls_el_df.rename(columns= {'elementary': 'school'})
mls_el_df
# Out:
#          mls                             school
# 0   90227486             GREGORY-LINCOLN ED CTR
# 1   76269817             GREGORY-LINCOLN ED CTR
# 2   44013547             GREGORY-LINCOLN ED CTR
# 3   78420188             GREGORY-LINCOLN ED CTR
# 4   32279965             GREGORY-LINCOLN ED CTR
# 5   12892280             GREGORY-LINCOLN ED CTR
# 6   47688089             GREGORY-LINCOLN ED CTR
# 7   14702643             GREGORY-LINCOLN ED CTR
# 8   23353569             GREGORY-LINCOLN ED CTR
# 9   95756492             GREGORY-LINCOLN ED CTR
# 10  52061919             GREGORY-LINCOLN ED CTR
# 11  13938486             GREGORY-LINCOLN ED CTR
# 12  77592370             GREGORY-LINCOLN ED CTR
# 13  87702589             GREGORY-LINCOLN ED CTR
# 14   8797838             GREGORY-LINCOLN ED CTR
# 15  43111391  WHARTON K-8 DUAL LANGUAGE ACADEMY
# 16  59046521             GREGORY-LINCOLN ED CTR
# 17  29513112             GREGORY-LINCOLN ED CTR
# 18  82691736             GREGORY-LINCOLN ED CTR
# 19  13863906             GREGORY-LINCOLN ED CTR
# 20  71466098             GREGORY-LINCOLN ED CTR
# 21  95801397             GREGORY-LINCOLN ED CTR
# 22  49786342             GREGORY-LINCOLN ED CTR
# 23  89590051             GREGORY-LINCOLN ED CTR
# 24  49821838             GREGORY-LINCOLN ED CTR
# 25  67264587             GREGORY-LINCOLN ED CTR
# 26  21315276             GREGORY-LINCOLN ED CTR
# 27  11725906                       MACGREGOR EL
# 28  56775365                       MACGREGOR EL

# %%
# creating high school potion of junction table
raw_mls_hs_df = HAR_df[['mls', 'high_school']]
mls_hs_df= raw_mls_hs_df.rename(columns= {'high_school': 'school'})
mls_hs_df
# Out:
#          mls       school
# 0   90227486    LAMAR H S
# 1   76269817    LAMAR H S
# 2   44013547    LAMAR H S
# 3   78420188    LAMAR H S
# 4   32279965    LAMAR H S
# 5   12892280    LAMAR H S
# 6   47688089    LAMAR H S
# 7   14702643    LAMAR H S
# 8   23353569    LAMAR H S
# 9   95756492    LAMAR H S
# 10  52061919    LAMAR H S
# 11  13938486    LAMAR H S
# 12  77592370    LAMAR H S
# 13  87702589    LAMAR H S
# 14   8797838    LAMAR H S
# 15  43111391    LAMAR H S
# 16  59046521    LAMAR H S
# 17  29513112    LAMAR H S
# 18  82691736  HEIGHTS H S
# 19  13863906  HEIGHTS H S
# 20  71466098  HEIGHTS H S
# 21  95801397  HEIGHTS H S
# 22  49786342  HEIGHTS H S
# 23  89590051  HEIGHTS H S
# 24  49821838  HEIGHTS H S
# 25  67264587    LAMAR H S
# 26  21315276    LAMAR H S
# 27  11725906    LAMAR H S
# 28  56775365    LAMAR H S

# %%
# concating HAR potion of junction table
frames = [mls_el_df,mls_hs_df]
all_mls_schools_df = pd.concat(frames)
all_mls_schools_df.to_csv('../Resources/all_mls_schools.csv', index = False)
all_mls_schools_df
# Out:
#          mls                             school
# 0   90227486             GREGORY-LINCOLN ED CTR
# 1   76269817             GREGORY-LINCOLN ED CTR
# 2   44013547             GREGORY-LINCOLN ED CTR
# 3   78420188             GREGORY-LINCOLN ED CTR
# 4   32279965             GREGORY-LINCOLN ED CTR
# 5   12892280             GREGORY-LINCOLN ED CTR
# 6   47688089             GREGORY-LINCOLN ED CTR
# 7   14702643             GREGORY-LINCOLN ED CTR
# 8   23353569             GREGORY-LINCOLN ED CTR
# 9   95756492             GREGORY-LINCOLN ED CTR
# 10  52061919             GREGORY-LINCOLN ED CTR
# 11  13938486             GREGORY-LINCOLN ED CTR
# 12  77592370             GREGORY-LINCOLN ED CTR
# 13  87702589             GREGORY-LINCOLN ED CTR
# 14   8797838             GREGORY-LINCOLN ED CTR
# 15  43111391  WHARTON K-8 DUAL LANGUAGE ACADEMY
# 16  59046521             GREGORY-LINCOLN ED CTR
# 17  29513112             GREGORY-LINCOLN ED CTR
# 18  82691736             GREGORY-LINCOLN ED CTR
# 19  13863906             GREGORY-LINCOLN ED CTR
# 20  71466098             GREGORY-LINCOLN ED CTR
# 21  95801397             GREGORY-LINCOLN ED CTR
# 22  49786342             GREGORY-LINCOLN ED CTR
# 23  89590051             GREGORY-LINCOLN ED CTR
# 24  49821838             GREGORY-LINCOLN ED CTR
# 25  67264587             GREGORY-LINCOLN ED CTR
# 26  21315276             GREGORY-LINCOLN ED CTR
# 27  11725906                       MACGREGOR EL
# 28  56775365                       MACGREGOR EL
# 0   90227486                          LAMAR H S
# 1   76269817                          LAMAR H S
# 2   44013547                          LAMAR H S
# 3   78420188                          LAMAR H S
# 4   32279965                          LAMAR H S
# 5   12892280                          LAMAR H S
# 6   47688089                          LAMAR H S
# 7   14702643                          LAMAR H S
# 8   23353569                          LAMAR H S
# 9   95756492                          LAMAR H S
# 10  52061919                          LAMAR H S
# 11  13938486                          LAMAR H S
# 12  77592370                          LAMAR H S
# 13  87702589                          LAMAR H S
# 14   8797838                          LAMAR H S
# 15  43111391                          LAMAR H S
# 16  59046521                          LAMAR H S
# 17  29513112                          LAMAR H S
# 18  82691736                        HEIGHTS H S
# 19  13863906                        HEIGHTS H S
# 20  71466098                        HEIGHTS H S
# 21  95801397                        HEIGHTS H S
# 22  49786342                        HEIGHTS H S
# 23  89590051                        HEIGHTS H S
# 24  49821838                        HEIGHTS H S
# 25  67264587                          LAMAR H S
# 26  21315276                          LAMAR H S
# 27  11725906                          LAMAR H S
# 28  56775365                          LAMAR H S

# %% [markdown]
# ## TEA Data

# %% [markdown]
# ### Extraction

# %%
# Store csv into df
csv_file= "../Resources/alt_school_rating_list_tea.csv"
raw_school_rating_df= pd.read_csv(csv_file)
raw_school_rating_df.head()
# Out:
#   Campus\nNumber                         Campus           District  \
# 0      024901001                 FALFURRIAS H S  BROOKS COUNTY ISD
# 1      024901041                 FALFURRIAS J H  BROOKS COUNTY ISD
# 2      024901101                  FALFURRIAS EL  BROOKS COUNTY ISD
# 3      024901103                     LASATER EL  BROOKS COUNTY ISD
# 4      024901105  FALFURRIAS INNOVATION ACADEMY  BROOKS COUNTY ISD
#
#    ESC\nRegion               Region  SBOE\nDistrict  \
# 0          1.0  REGION 01: EDINBURG             3.0
# 1          1.0  REGION 01: EDINBURG             3.0
# 2          1.0  REGION 01: EDINBURG             3.0
# 3          1.0  REGION 01: EDINBURG             3.0
# 4          1.0  REGION 01: EDINBURG             3.0
#
#    # of Consecutive Years Campus is Academically Unacceptable  \
# 0                                                0.0
# 1                                                1.0
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#                       Campus 2020 Rating Campus 2019 Rating  \
# 0  Not Rated: Declared State of Disaster                  B
# 1  Not Rated: Declared State of Disaster                  F
# 2  Not Rated: Declared State of Disaster                  C
# 3  Not Rated: Declared State of Disaster                  C
# 4  Not Rated: Declared State of Disaster                NaN
#
#   Campus 2018 Rating Campus 2017 Rating Campus 2016 Rating  \
# 0       Met Standard       Met Standard       Met Standard
# 1       Met Standard       Met Standard       Met Standard
# 2       Met Standard       Met Standard       Met Standard
# 3       Met Standard       Met Standard       Met Standard
# 4                NaN                NaN                NaN
#
#      Campus 2015 Rating Campus 2014 Rating Campus 2013 Rating  \
# 0          Met Standard       Met Standard       Met Standard
# 1  Improvement Required       Met Standard       Met Standard
# 2          Met Standard       Met Standard       Met Standard
# 3          Met Standard       Met Standard       Met Standard
# 4                   NaN                NaN                NaN
#
#    Campus 2012 Rating         Campus 2011 Rating
# 0                 NaN  Academically Unacceptable
# 1                 NaN  Academically Unacceptable
# 2                 NaN    Academically Acceptable
# 3                 NaN    Academically Acceptable
# 4                 NaN                        NaN

# %% [markdown]
# ### Transformation

# %%
# removing columns not needed
raw_school_rating1_df = raw_school_rating_df.drop(['ESC\r\nRegion', 'Region', 'SBOE\r\nDistrict','Campus 2020 Rating',
                                                  'Campus 2018 Rating', 'Campus 2017 Rating','Campus 2016 Rating',
                                                  'Campus 2015 Rating', 'Campus 2014 Rating','Campus 2013 Rating',
                                                  'Campus 2012 Rating','Campus 2011 Rating'], axis =1)
raw_school_rating1_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-1639f15b7598> in <module>
#       1 # removing columns not needed
# ----> 2 raw_school_rating1_df = raw_school_rating_df.drop(['ESC\r\nRegion', 'Region', 'SBOE\r\nDistrict','Campus 2020 Rating',
#       3                                                   'Campus 2018 Rating', 'Campus 2017 Rating','Campus 2016 Rating',
#       4                                                   'Campus 2015 Rating', 'Campus 2014 Rating','Campus 2013 Rating',
#       5                                                   'Campus 2012 Rating','Campus 2011 Rating'], axis =1)
#
# ~\anaconda3\envs\DBEnv\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# ~\anaconda3\envs\DBEnv\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\envs\DBEnv\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\envs\DBEnv\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['ESC\\r\\nRegion' 'SBOE\\r\\nDistrict'] not found in axis"

# %%
# Renaming columns - int is for intermediate (in process) table
int_school_rating_df= raw_school_rating1_df.rename(columns= {'Campus\r\nNumber': 'campus_number',
                                                            'Campus' : 'school',
                                                            'District' : 'district',
                                                          '# of Consecutive Years Campus is Academically Unacceptable' : 'yrs_unacceptable',
                                                          'Campus 2019 Rating' : 'rating'})
int_school_rating_df

# %%
# Adding in new column and associated value
int_school_rating_df['year']= 2019
int_school_rating_df

# %%
# Dropping rows that contain notes, i.e. start with *
int_school_ratinga_df = int_school_rating_df.drop(int_school_rating_df.loc[int_school_rating_df.campus_number.str.startswith("*")].index)
int_school_ratinga_df

# %%
# Dropping rows that contain middle school to match HAR data
int_school_rating1_df = int_school_ratinga_df.drop(int_school_ratinga_df.loc[int_school_ratinga_df.school.str.contains("MIDDLE")].index)
int_school_rating1_df

# %%
# checking for NANs
int_school_rating1_df.isna().sum()

# %%
# filling NaNs
int_school_rating1_df = int_school_rating1_df.fillna("Not Rated")

# %%
# checking for NANs
int_school_rating1_df.isna().sum()

# %%
# looking for unique items in column
int_school_rating1_df.rating.unique()

# %%
# replacing to get like wording 
int_school_rating2_df = int_school_rating1_df.replace({"rating" :"Not Rated: Minimum Size rules"},"Not Rated", regex = True)
int_school_rating3_df = int_school_rating2_df.replace({"rating" :"Not rated: Data Integrity Issue"},"Not Rated", regex = True)
int_school_rating3_df.head()

# %%
# verifying like wording
int_school_rating3_df.rating.unique()

# %%
# building dataframe for customer target area
int_school_rating4_df = int_school_rating3_df.loc[(int_school_rating_df['district'] == "HOUSTON ISD")|
                                               (int_school_rating_df['district'] == "KATY ISD") |
                                               (int_school_rating_df['district'] == "SHELDON ISD") |
                                               (int_school_rating_df['district'] == "SPRING BRANCH ISD") |
                                               (int_school_rating_df['district'] == "GALENA PARK ISD") |
                                               (int_school_rating_df['district'] == "CYPRESS-FAIRBANKS ISD") 
                                               ]
int_school_rating4_df

# %%
# adding high schools that are on edge of target area (outside of ISD) but still gets kids because of zoning
new_df = int_school_rating3_df.loc[(int_school_rating3_df['campus_number'] =='101911002')]
new1_df = int_school_rating3_df.loc[(int_school_rating3_df['campus_number'] =='101902003')]
new2_df = int_school_rating3_df.loc[(int_school_rating3_df['campus_number'] =='101919001')]

# %%
# adding schools to df
int_school_rating5_df = int_school_rating4_df.append(new_df, ignore_index=True)
int_school_rating6_df = int_school_rating5_df.append(new1_df, ignore_index=True)
int_school_rating7_df = int_school_rating6_df.append(new2_df, ignore_index=True)
int_school_rating7_df

# %%
# removing elementary school that is not in the target area ISD - it was causing conflict with primary key
int_school_rating8_df = int_school_rating7_df[int_school_rating7_df.campus_number != '101907152']
int_school_rating8_df

# %%
# Creating duplicate df to prevent corruption of original df
school_rating_df= int_school_rating8_df
school_rating_df

# %%
# Writing to clean csv
school_rating_df.to_csv('../Resources/alt_clean_ratings.csv', index = False)

# %%
raw_cnum_school_df = school_rating_df[['campus_number','school']]
raw_cnum_school_df .to_csv("../Resources/raw_cnum_school.csv", index = False)
raw_cnum_school_df

# %%
raw_junction = pd.merge_ordered(all_mls_schools_df, raw_cnum_school_df, fill_method='ffill', left_by='school')
raw_junction.to_csv("../Resources/raw_junction.csv", index = False)
raw_junction

# %%
# triple mls check - if dup school names in target area - will cause 3 mls nubers to show
trip_school_rating = raw_junction.pivot_table(index= ['mls'], aggfunc= 'size')
trip_school_rating.sort_values(ascending=False)

# %%
sorted_raw_junction = raw_junction.sort_values(by=['mls'])
sorted_raw_junction

# %%
raw_har2_df = sorted_raw_junction.drop(['school'], axis =1)
raw_har2_df

# %%
# # Writing to clean csv
raw_har2_df .to_csv("../Resources/raw_har2.csv", index = False)

# %% [markdown]
# ## Junction Table

# %%
# Store csv into df
csv_file= "../Resources/raw_HAR2.csv"
junction_df= pd.read_csv(csv_file)
junction_df

# %% [markdown]
# # Load to SQL

# %%
# Connect to local database
rds_connection_string = f"{username}:{password}@localhost:5432/etl_team5"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Use pandas to load transformed df into table school_rating_df
school_rating_df.to_sql(name='school_rating', con=engine, if_exists='replace', index=False)

# %%
# Use pandas to load transformed df into table mls
HAR_df.to_sql(name='mls', con=engine, if_exists='replace', index=False)

# %%
# Use pandas to load transformed df into table junction_table
junction_df.to_sql(name='junction_table', con=engine, if_exists='replace', index=False)

# %% [markdown]
# ## SQL Query of tables

# %%
# Confirm data has been added by querying the school_rating table
pd.read_sql_query('select * from school_rating', con=engine).head()

# %%
# Confirm data has been added by querying the mls table
pd.read_sql_query('select * from mls', con=engine).head()

# %%
# Confirm data has been added by querying the junction_table table
pd.read_sql_query('select * from junction_table', con=engine).head()

# %%
# Check for tables
engine.table_names()
